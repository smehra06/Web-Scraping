# %% [markdown]
# **Final Project DBMS** <br>
# **Group members:** Satvir Kaur <br>
# **Instructor:** Mario Soriano Morales <br>
# **Due Date:** April 20, 2024 <br>

# %% [markdown]
# # Final Project - Examining scrapped data from Kijiji and RentFaster using Spark and Yelp API [Partnership with Community Data Program]
#
# **Overview**
#
# In the dynamic field of Data/ML, engaging with Application Programming Interfaces (APIs) is a common practice, enabling the extraction of data or interaction with software. Nonetheless, not all applications/services offer API so it is important to understand how to extract data even in cases where an API is not available. Similarly, adapting to various data management techniques is essential across different companies or organizations. This project centers around gathering data from rental listings within Alberta, Canada, specifically focusing on platforms such as Kijiji and RentFaster. Additionally, you will be leveraging the Yelp API, you'll identify highly rated restaurants and analyze their proximity to these rental listings you scraped from RentFaster and Kijiji.
#
# The data acquisition phase is facilitated through a pre-developed web scraper, designed to streamline the process of extracting rental listings. This initiative is in collaboration with the Community Data Program, aiming to make rental listing data within Canada more accessible to communities with limited access. Initially focusing on Alberta, this project sets the groundwork for future expansion across other regions.
#
# Your task involves determining the pertinent data to extract, followed by managing this data within a distributed system, namely Apache Spark. Subsequently, you will perform data analysis and processing utilizing Spark SQL. This final project encourages collaboration in groups of up to 3 members (you are allowed to use the same members as your midterm), where active participation from all members is expected. It's crucial to note that your presentation will constitute 30% of your overall score, highlighting the importance of both teamwork and individual effort in the successful completion of this project.
#
# **Deliverables**
#
#
# 1.  Your main jupyter notebook file with the proper execution of:
#    *  Part 1: Data Collection
#    *  Part 2: DataFrame, Tables creation and Yelp API setup
#    *  Part 3: Explore your data
# 2.  The data collected from Part 1 in CSV format (Total of 4 CSV files for both Kijiji and RentFaster)
# 3.  A presentation (done using the software of your choosing, PowerPoint, Canvas etc) where you will showcase Part 1 to 3 of your project. What we are specifically looking is the following:
#    *  Issues faced acquiring your data, this could be limitations with the web scraping procedure
#    *  Data quality issues such as missing values or difficulties when working with multiple data types and how to solve/consider those in your analysis
#    *  The highlights and correlations that you derived based on the analysis of the data, you should be able to answer the following questions:
#        * Is there a correlation between the rental price vs the quality/price of restaurants nearby?
#        * Is the data coming from Yelp of enough quality to drive insides?
#        * What would you do better or different to arrive at a more conclusive analysis?
#        * What are your next steps?
#        * Is this data pipeline you built enough to scale for big data?
#
# **Important NOTES**
#
#
# The presentation **IS NOT GOING TO BE A RECORDING**. It will be a live presentation either in-person or online where I will engage in questions with all of the team. If a member is not present, that person will lose automatically 30% of the total grade of the Final.
#
#
# *InPerson Students*
#
#
# *  The presentation will be held in-person on Monday April 22nd and Tuesday
# April 23rd (time to be decided).
#
#
# *Hyflex Students*
# *  You have the opportunity to present in-person (if you can make it) or schedule an online presentation with me. Either way you need to let me know
#
#
# **Due Date** You have until Saturday April 20th at Midnight to submit your code. But you still have time to work on your presentation as the presentation will be held on the 22th and 23th.

# %% [markdown]
# ## Web Scraping Code
# In this section you will find everything you need to know about the Scraper we have built for you to get data from rentals within AB from RentFaster and Kijiji

# %% [markdown]
# ### Working with PlayWright
#
# Playwright is a tool developed by Microsoft that allows developers to automate interactions with web browsers. In simpler terms, it can control browsers programmatically to perform tasks like navigating through web pages, clicking buttons, filling out forms, and extracting information from websites, all through a script or program.
#
# Here’s why Playwright is particularly useful for web scraping rental listings in RentFaster and Kijiji:
# 1. **Supports Multiple Browsers**: Playwright can control different browsers (like Chrome, Firefox, and Safari) using a single API. This makes it easier to scrape websites as they appear in various browsers without needing to adjust your code significantly for each one.
#
# 2. **Headless Browsing**: It can run browsers in 'headless' mode, meaning it can navigate and interact with websites without actually opening a browser window. This speeds up the scraping process and allows for running scrapers on servers or in environments where a graphical interface is not available.
#
# 3. **Automates Complex Interactions**: Some websites require complex interactions to access their data, like logging in, navigating through menus, or interacting with JavaScript. Playwright can automate these interactions, making it possible to scrape data from sites that would be difficult or impossible to scrape with simpler tools.
#
# Learn more about it! https://playwright.dev/python/docs/intro

# %%
# !pip install playwright
# !playwright install
# Out:
# Collecting playwright
#   Downloading playwright-1.43.0-py3-none-manylinux1_x86_64.whl (37.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.3/37.3 MB 15.1 MB/s eta 0:00:00
# Requirement already satisfied: greenlet==3.0.3 in /usr/local/lib/python3.10/dist-packages (from playwright) (3.0.3)
# Collecting pyee==11.1.0 (from playwright)
#   Downloading pyee-11.1.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from pyee==11.1.0->playwright) (4.11.0)
# Installing collected packages: pyee, playwright
# Successfully installed playwright-1.43.0 pyee-11.1.0
# Downloading Chromium 124.0.6367.29 (playwright build v1112) from https://playwright.azureedge.net/builds/chromium/1112/chromium-linux.zip
# 155.3 MiB [] 0% 0.0s155.3 MiB [] 0% 40.0s155.3 MiB [] 0% 27.6s155.3 MiB [] 0% 27.7s155.3 MiB [] 0% 23.8s155.3 MiB [] 0% 18.8s155.3 MiB [] 0% 17.1s155.3 MiB [] 0% 18.0s155.3 MiB [] 0% 15.4s155.3 MiB [] 1% 13.6s155.3 MiB [] 1% 12.3s155.3 MiB [] 1% 11.3s155.3 MiB [] 1% 10.9s155.3 MiB [] 2% 10.4s155.3 MiB [] 2% 10.1s155.3 MiB [] 2% 10.2s155.3 MiB [] 2% 10.0s155.3 MiB [] 3% 9.7s155.3 MiB [] 3% 9.3s155.3 MiB [] 3% 9.1s155.3 MiB [] 4% 9.0s155.3 MiB [] 4% 8.9s155.3 MiB [] 4% 9.1s155.3 MiB [] 4% 8.9s155.3 MiB [] 5% 8.6s155.3 MiB [] 5% 8.7s155.3 MiB [] 5% 8.8s155.3 MiB [] 5% 8.5s155.3 MiB [] 6% 8.2s155.3 MiB [] 6% 8.1s155.3 MiB [] 6% 7.8s155.3 MiB [] 7% 7.6s155.3 MiB [] 7% 7.4s155.3 MiB [] 7% 7.5s155.3 MiB [] 8% 7.2s155.3 MiB [] 9% 7.2s155.3 MiB [] 9% 7.1s155.3 MiB [] 9% 7.2s155.3 MiB [] 10% 7.0s155.3 MiB [] 10% 6.9s155.3 MiB [] 11% 6.8s155.3 MiB [] 11% 6.7s155.3 MiB [] 12% 6.7s155.3 MiB [] 12% 6.5s155.3 MiB [] 13% 6.3s155.3 MiB [] 13% 6.2s155.3 MiB [] 14% 6.1s155.3 MiB [] 14% 5.9s155.3 MiB [] 14% 6.0s155.3 M
# ╚══════════════════════════════════════════════════════╝
#     at validateDependenciesLinux (/usr/local/lib/python3.10/dist-packages/playwright/driver/package/lib/server/registry/dependencies.js:216:9)
#     at async Registry._validateHostRequirements (/usr/local/lib/python3.10/dist-packages/playwright/driver/package/lib/server/registry/index.js:587:43)
#     at async Registry._validateHostRequirementsForExecutableIfNeeded (/usr/local/lib/python3.10/dist-packages/playwright/driver/package/lib/server/registry/index.js:685:7)
#     at async Registry.validateHostRequirementsForExecutablesIfNeeded (/usr/local/lib/python3.10/dist-packages/playwright/driver/package/lib/server/registry/index.js:674:43)
#     at async t.<anonymous> (/usr/local/lib/python3.10/dist-packages/playwright/driver/package/lib/cli/program.js:119:7)

# %% [markdown]
# ### Web Scraping Libraries - Explained
#
# When scraping rental listings from websites like Kijiji and RentFaster, several Python libraries will be of use in the process. Here's how each of them contributes:
#
# - **`asyncio`**: This is a library to write concurrent code using the async/await syntax. It is useful for handling asynchronous operations, making it possible to scrape websites more efficiently. When used with `playwright`, it allows for asynchronous navigation and interaction with web pages, speeding up the web scraping process by performing multiple tasks concurrently.
#
# - **`json`**: JavaScript Object Notation (JSON) is a lightweight data interchange format. This library can be used to parse JSON data that will be returned from HTML requests on rental websites and to store scraped data in a JSON format, making it easier to work with complex data structures using Spark.
#
# - **`requests`**: A powerful HTTP library for making requests to web servers. It is used to request the HTML content of web pages from Kijiji and RentFaster. `requests` is straightforward and can handle various types of HTTP requests, essential for accessing the data on rental listings.
#
# - **`time`**: This module provides various time-related functions. We will use it to handle rate limiting by adding delays between requests, ensuring that your scraping activities do not lead to your IP being banned from the website for making too many requests too quickly.
#
# - **`re` (Regular Expression)**: This library is used to search, match, or replace patterns in strings. In our web scraping process, is particularly useful for extracting specific pieces of data from HTML or text, such as phone numbers, prices, or other structured information from rental listings.
#
# - **`pandas` (pd)**: A powerful data manipulation and analysis library. After scraping the data, `pandas` can be used to clean, transform, and analyze the rental listings data, making it easier to work with large datasets and perform complex data analysis tasks.
#
# - **`csv`**: This module implements classes to read and write tabular data in CSV format. It can be used to save scraped data into CSV files, which is a common format for storing tabular data, allowing for easy sharing and analysis of the scraped rental listings.
#
# - **`BeautifulSoup` (from `bs4`)**: A library for parsing HTML and XML documents. It creates parse trees that is helpful to extract information from web pages easily. `BeautifulSoup` works well with `requests` to navigate the HTML structure of a page and extract data, such as rental prices, descriptions, and images.
#
# - **`playwright.async_api` (async_playwright, TimeoutError)**: `playwright` is a framework for browser automation and `async_playwright` refers to its asynchronous API. This is particularly useful for interacting with JavaScript-heavy websites like RentFaster, allowing for headless browser interaction, page navigation, and dynamic content loading. The `TimeoutError` helps in handling exceptions that may occur if a page takes too long to load or respond.

# %%
import asyncio
import json
import requests
import time
import re
import pandas as pd
import csv
import numpy as np
from bs4 import BeautifulSoup
# Import async playwright
from playwright.async_api import async_playwright, TimeoutError, Error

# %% [markdown]
# ### Get HTML content from Website - PlayWright
#
# The `get_page_content` function is an asynchronous utility designed for web scraping, specifically optimized for fetching content from RentFaster and Kijiji. It employs the Playwright library to programmatically control a web browser, navigating to a specified URL and waiting for the page to load fully before capturing its HTML content. This is particularly useful for RentFaster that dynamicaly loads content asynchronously with JavaScript.
#
# The function is capable of making multiple attempts to fetch a page's content, retrying up to a predefined limit in case of timeouts, which can occur with Kijiji. This retry mechanism, coupled with the ability to wait for specific page elements to appear before proceeding, ensures reliability in the scraping process. It can specifically wait for elements that signify the page has fully loaded on either RentFaster or Kijiji, based on parameters passed to it. After successfully retrieving the page content, the browser session is closed to clean up resources. If the function fails to fetch the content after the specified number of retries, it raises an exception to signal the failure. This approach ensures robustness and flexibility in scraping tasks, accommodating the challenges posed these websites.

# %%
async def get_page_content(url, wait_rf, wait_kk, retries=5):
    attempt = 0
    while attempt < retries:
        try:
            async with async_playwright() as p:
                # Launch the browser
                browser = await p.chromium.launch()
                page = await browser.new_page()

                # Navigate to the URL
                await page.goto(url)
                if wait_rf:
                    # Wait for a selector to ensure the page has loaded (rent-faster)
                    await page.wait_for_selector('.card.my-3.p-3.ng-scope', timeout=6000)
                if wait_kk:
                    # Wait for a selector to ensure the page has loaded (kijiji)
                    await page.wait_for_selector('ul[data-testid="srp-search-list"]', timeout=6000)
                await asyncio.sleep(1)
                # Get the page content
                content = await page.content()
                # Close the browser
                await browser.close()

                return content
        except (TimeoutError, Error) as e:
            print(f"Attempt {attempt + 1} failed with error {e}, retrying...")
            attempt += 1
            if attempt < retries:
                await asyncio.sleep(2)  # Wait a bit before retrying

    # If all attempts fail, raise an exception or return a specific value
    raise Exception(f"All {retries} attempts failed.")

# %% [markdown]
# ### Retrieve URLs from listing website -   Kijiji
# The `get_urls_kk` function is an asynchronous function crafted to parse URLs from the HTML content of a Kijiji listing page, a task preceded by fetching the page content with the `get_page_content` function. Utilizing the BeautifulSoup library, the function interprets the HTML to find specific anchor (`<a>`) tags that denote listing links on Kijiji.
#
# This method is finely tuned for the structure of Kijiji's website, making use of distinct HTML attributes to precisely extract and construct URLs for each listing. It plays an essential role in web scraping workflows aimed at navigating from a general listings page to specific listings for more detailed data extraction.

# %%
async def get_urls_kk(content):
    soup = BeautifulSoup(content, 'html.parser')
    urls = []
    links = soup.find_all('a', {'data-testid': 'listing-link'}, href=True)
    for link in links:
        urls.append('https://www.kijiji.ca' + link['href'])
    return urls

# %% [markdown]
# ### Retrieve URLs from listing website - RentFaster
#
# The `get_urls_rf` function is designed to extract URLs from the HTML content of a RentFaster listing page. Unlike the previous function focused on Kijiji, this one deals with structured data embedded within a `<script>` tag in JSON format, a common technique for web developers to initialize JavaScript objects on web pages.
#
# This function highlights a different approach to web scraping, focusing on extracting data from JSON embedded within HTML content, which can be a more direct and less error-prone method than parsing the HTML structure itself, especially when the website utilizes JavaScript to render content dynamically.

# %%
back_up_details = {}
back_up_overviews = {}

def get_urls_rf(content):
    soup = BeautifulSoup(content, 'html.parser')
    script_tag = soup.find('script', id='ldjsonProperties')
    json_str = script_tag.string if script_tag else ''

    # Check if we successfully found the script tag and extracted the string
    if not json_str:
        print("JSON string not found.")
    else:
        data = json.loads(json_str)
        urls = []
        # Check if the key 'itemListElement' is in the parsed data
        if 'itemListElement' in data:
            # Iterate through each item and extract the 'url'
            for item in data['itemListElement']:
                url = item.get('url', None)
                if url:
                    urls.append(url)
        return urls

# %% [markdown]
# ### Generate URLs from both website programmatically
#
# This functions deals with creating a list of listings and their URLs for both Kijiji and RentFaster. It is designed to call the functions we defined above based on the following parameters:
#
#
# *   `parameter` : Can be the a location within Alberta if `rentfaster` is `True`, or it can be a `page` number based on which page from a listing we want to get the URLs from if `kijiji` is `True`
# *   `kijiji`: Boolean True or False
# *   `rentfaster`: Boolean True or False

# %%
async def url_generator(parameter,kijiji,rentfaster):
  contents_urls = []
  if rentfaster:
    for location in parameter:
      url = f'https://www.rentfaster.ca/ab/{location}/#dialog-listview'
      content = await get_page_content(url,True,False)
      time.sleep(1)
      print(f"Getting listing URLs for {location} [RentFaster]")
      urls = get_urls_rf(content)
      contents_urls.append(urls)
      time.sleep(1)
    print("URLs retrieved")
    return contents_urls
  elif kijiji:
    for n in range(1, len(parameter) + 1):
      url = f"https://www.kijiji.ca/b-for-rent/alberta/page-{parameter[n-1]}/c30349001l9003"
      print(f"Getting listing URLs for AB page {parameter[n-1]} [Kijiji]")
      content = await get_page_content(url, wait_rf = False, wait_kk = True)
      time.sleep(1)
      urls = await get_urls_kk(content)
      contents_urls.append(urls)
      time.sleep(1)
    print("URLs retrieved")
    return contents_urls
  else:
    print("Invalid Options")
    return None

# %% [markdown]
# ### Scraping and Parsing content from Website
# To understand the structure and dynamics of HTML content fetched from Kijiji and RentFaster is important to effectively use web scraping, especially when extracting detailed information about rental listings. This complexity arises because websites such as RentFaster often employ dynamic content loading through JavaScript, which means the data you're interested in (e.g., address, price, listing title, description, features of the listing like pet-friendliness or laundry facilities, contact info, posting date, URL) may not be present in the initial HTML served by the web server but loaded asynchronously thereafter.
#
# Given these challenges, tailored approaches are necessary for scraping each website. These functions are meticulously designed to navigate the intricacies of each site's HTML structure and JavaScript dynamics.
#
# RentFaster, for instance, stores relevant listing details within `<script>` tags in JSON format. The parsing function for RentFaster content is adept at locating these tags, extracting and decoding the JSON, and then systematically pulling out and organizing the necessary data, such as property overview, amenities, and unit details. This method hinges on the JSON being structured in a predictable manner, allowing for direct access to various pieces of information without the need to interpret the HTML visually as a browser would.
#
# On the other hand, the Kijiji content parsing function deals with a more traditional mix of HTML elements and embedded JSON scripts. It has to navigate through the document, identifying specific tags and classes to extract the listing’s description, address, and other attributes. This function also handles dynamically loaded data, requiring it to parse both the visible HTML and the JavaScript variables or window properties that contain JSON data with additional details about the listings.
#
# The need for these tailored functions arise from the variance in how each website delivers content to the end-user. While one site might embed data within HTML in a straightforward manner, another might rely heavily on JavaScript to construct the page dynamically, necessitating a flexible and nuanced approach to scraping.
#
# This project highlights a broader principle in web scraping: the importance of carefully analyzing the source content of a website to understand how it structures and delivers data. This analysis is crucial for designing efficient scrapers that can reliably extract the needed information despite the complexities of modern web development practices, including the use of JavaScript and AJAX for dynamic content loading. Such an understanding not only informs the technical strategy for data extraction but also ensures the scraper can adapt to changes in the website's structure or content delivery mechanisms over time.

# %%
# @title #### RentFaster Parser Function
def parse_json_data_rf(content, url):
    soup = BeautifulSoup(content, 'html.parser')
    script_tags = soup.find_all("script", type="application/ld+json")
    match = re.search(r'https://www\.rentfaster\.ca(/[^/]+/[^/]+)/', url)
    location = match.group(1)
    data = None
    for tag in script_tags:
        try:
            if tag.string != None:
              json_data = json.loads(tag.string)
              if 'mainEntity' in json_data:
                  data = json_data['mainEntity']
                  break
        except json.JSONDecodeError:
            continue

    if data is None:
      print("No valid JSON data found for the provided listing. Skipping Listing")
      return
    # Extract the ID from the URL
    property_id = re.search(r'(\d+)$', data.get("@id", "")).group(1) if data.get("@id") else None

    property_overview = {
        "id": property_id,
        "location": location,
        "name": data.get("name", "Undefined"),
        "url": data.get("url", "Undefined"),
        "slogan": data.get("slogan", "Undefined"),
        "priceRange": data.get("priceRange", "Undefined"),
        "telephone": data.get("telephone", "Undefined"),
        "image": data.get("image", "Undefined"),
        "description": data.get("description", "Undefined")
    }
    if "address" in data:
      address_parts = [
          data["address"].get("streetAddress", ""),
          data["address"].get("addressLocality", ""),
          data["address"].get("addressRegion", ""),
          data["address"].get("postalCode", ""),
          data["address"]["addressCountry"].get("name", "")
      ]
      # Filter out empty strings and join with a comma
      property_overview["address"] = ', '.join(filter(None, address_parts))
    else:
      property_overview["address"] = "Undefined"

    # Conditionally add amenities if they exist
    if "amenityFeature" in data:
      property_overview["amenities"] = {feature.get("name", ""): feature.get("value", "") for feature in data["amenityFeature"]}
    else:
      property_overview["amenities"] = {"Undefined"}

    # Update the global dictionary for property overviews
    all_property_overviews[property_id] = property_overview

    # Extract and restructure unit details
    unit_details = [
        {
            "property_id": property_id,  # Link to property by ID
            "unit_name": unit["name"],
            "description": unit["description"],
            "squareFeet": next((prop["value"] for prop in unit["additionalProperty"] if prop["name"] == "Square Feet"), None),
            "availabilityDate": next((prop["value"] for prop in unit["additionalProperty"] if prop["name"] == "Availability Date"), None),
            "utilitiesIncluded": next((prop["value"] for prop in unit["additionalProperty"] if prop["name"] == "Utilities Included"), None)
        } for unit in data.get("containsPlace", [])
    ]

    for unit_detail in unit_details:
        # Sanitize the unit_name to remove spaces and special characters for use as a key
        sanitized_unit_name = re.sub(r'\W+', '_', unit_detail["unit_name"])  # Replace non-word characters with underscore
        key = f'{property_id}_{sanitized_unit_name}'
        all_unit_details[key] = unit_detail

# %%
# @title #### Kijiji Parser Function
def parse_json_data_kk(content, link):

  script_content_var = None
  script_content_window = None
  match_link = re.search(r'/(\d+)$', link)
  property_id = match_link.group(1)
  soup = BeautifulSoup(content, 'html.parser')

  # Find the meta tag with the name 'description'
  description_container = soup.find('div', class_='descriptionContainer-2067035870')
  if description_container and description_container.div:
      description = description_container.div.get_text(separator='\n').strip()
  else:
      description = "Undefined"

  # Find address
  adLocation_tags = soup.find_all('span', itemprop="address")

  adLocation = {f"address_{index+1}": tag.get_text().strip()
                    for index, tag in enumerate(adLocation_tags)} if adLocation_tags else {"Undefined": "Undefined"}

  # Find date posted - Assuming this extracts the text correctly, or you might need to adjust based on actual content
  date = soup.select_one("div[class*=datePosted-1776470403]").get_text() if soup.select_one("div[class*=datePosted-1776470403]") else "Undefined"

  script_tag_var = soup.find('script', string=re.compile('var dataLayer ='))
  if script_tag_var is not None:
      script_content_var = script_tag_var.string
      match_var = re.search(r'var dataLayer = (\[.*?\]);', script_content_var, re.DOTALL)
      if match_var:
        data_layer = json.loads(match_var.group(1))
        item = data_layer[0]
        price_info = item.get('a', {}).get('prc', {})
  else:
    price_info = "Undefined"

  script_tag_window = soup.find('script', string=re.compile('window\.__data'))
  if script_tag_window is not None:
      script_content_window = script_tag_window.string
      match_window = re.search(r'window\.__data=(\{.*?\});', script_content_window, re.DOTALL)
      if match_window:
        data = json.loads(match_window.group(1))
        ad_info = data.get("config", {}).get("VIP", {})
        ad_location = ad_info.get("adLocation", {})
        ad_attributes = ad_info.get("adAttributes", {})
        attributes_dict = {}
        for attr in ad_attributes:
          label = attr['localeSpecificValues']['en']['label']
          value = attr['localeSpecificValues']['en']['value']
          attributes_dict[label] = value
  else:
    attributes_dict = "Undefined"

  all_property_overviews_kk[property_id] = {
      "listing_url": link,
      "date_posted": date,
      "address" : adLocation,
      "price_info": price_info,
      "description": description
  }
  all_unit_details_kk[property_id] = attributes_dict

# %%
# @title #### Parser based on CSV with URLs
async def scrape_urls_from_csv(filename,website):
    urls = []
    # Read URLs from CSV
    with open(filename, 'r', newline='') as csvfile:
        reader = csv.reader(csvfile)
        for row in reader:
            if row:  # Check if the row is not empty
                urls.append(row[0])
    total_urls = len(urls)
    print(f"URLs extracted from the CSV file: {filename}. Total URLs to scrape: {total_urls}")

    # Scraping loop
    for index, url in enumerate(urls, start=1):
        content = await get_page_content(str(url), wait_rf=False, wait_kk=False)
        print(f"Scraping started for {url}. [{index}/{total_urls}]")
        await asyncio.sleep(0.5)
        if website == 'kijiji':
          parse_json_data_kk(content, url)
        elif website == 'rentfaster':
          parse_json_data_rf(content, url)
        print(f"Scraped {index} urls out of {total_urls} total.")

    print("Scraping Finished")

# %% [markdown]
# ### Data Transformation Toolkit
# General functions to covert data into CSV and DataFrame

# %%
# @title #### Create csv - RentFaster/Kijiji
def convert_to_tables(all_property_overviews, all_unit_details, filename_overview, filename_details):
    # Convert dictionaries to dataframes, including the keys as a new column
    property_overviews_df = pd.DataFrame.from_dict(all_property_overviews, orient='index').reset_index()
    unit_details_df = pd.DataFrame.from_dict(all_unit_details, orient='index').reset_index()

    # Rename the 'index' column to 'property_id'
    property_overviews_df.rename(columns={'index': 'property_id'}, inplace=True)
    unit_details_df.rename(columns={'index': 'property_id'}, inplace=True)

    # Example: Save to CSV
    property_overviews_df.to_csv(filename_overview, index=False)
    unit_details_df.to_csv(filename_details, index=False)

def convert_rentfaster_to_csv(all_unit_details,all_property_overviews,csv_file_path_details,csv_file_path_overview):
    #converting details data into csv
    df_details = pd.DataFrame.from_dict(all_unit_details, orient='index').reset_index().rename(columns={'index':'unit_id'})
    df_details['description'] = df_details['description'].str.replace(',','')
    df_details['unit_name'] = df_details['unit_name'].str.replace(',','')
    df_details.to_csv(csv_file_path_details, index=False)

    #converting overview data into csv
    df_o = pd.DataFrame.from_dict(all_property_overviews, orient='index').reset_index().rename(columns={'index':'property_id'})
    df_o['description'] = df_o['description'].apply(lambda x: re.sub(r'[^A-Za-z0-9 ]+', '', x))
    df_o.to_csv(csv_file_path_overview, index=False)

def convert_kijiji_to_csv(all_unit_details,all_property_overviews,csv_file_path_details,csv_file_path_overview):
    #converting details data into csv
    df_details = pd.DataFrame.from_dict(all_unit_details, orient='index').reset_index().rename(columns={'index':'unit_id'})
    df_details.to_csv(csv_file_path_details, index=False)

    #converting overview data into csv
    df_o = pd.DataFrame.from_dict(all_property_overviews, orient='index').reset_index().rename(columns={'index':'unit_id'})
    df_o['description'] = df_o['description'].apply(lambda x: re.sub(r'[^A-Za-z0-9 ]+', '', x))
    df_o.to_csv(csv_file_path_overview, index=False)

# %%
# @title #### Convert list of URLs into CSV
def convert_to_csv(data, filename):
  # Open the file in write mode ('w') and create a csv.writer object
  count = 0
  with open(filename, 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    # Write each row to the CSV file
    for list_ in data:
      for link in list_:
        count += 1
        writer.writerow([link])

  print(f"CSV file '{filename}' created successfully. Number of Links: {count}")

# %% [markdown]
# ## Part 1: Getting your datasets from Web Scraping [Data Collection - Total 20 pts]
#
#
# **Objective**: Create 4 CSVs on the data scraped from Kijiji and RentFaster.
#
# For RentFaster, we have selected all cities/areas from AB. We can expand the search and include more provinces as need it but not required. You can select up to 25 locations across Alberta to get the listing data from Rent Faster.
#
# For Kijiji, we will be selecting listings from the following [URL](https://www.kijiji.ca/b-for-rent/alberta/page-1/c30349001l9003) and you can pick the number of listing pages you want to scrape links from. The total listing pages are 190. Each page contains 40 listings so you can get up to 7600 URLs from the website, but you are not required to get all the data.
#
#
# In order to get the 20 pts from this step you will need to perform the following:
#
# *   Select 1 major city (either Edmonton or Calgary) + 5 other locations. The total selected cities/areas need to be 6, which will be approximately 600+ listings. This can be done in **Step 1**
# *   Select 1 or up to 3 page ranges from **Step 2**. The total numbers generated by the ranges you picked CANNOT be more than 12. Here is an example of a proper range selection:
#
#     * range 1 = [20 - 25], range 2 = [9 - 11], range 3 = [3 - 5] -> Numbers generated [3, 4, 5, 9, 10, 11, 20, 21, 22, 23, 24, 25] Total of 12 page numbers
# *   Run cells from Step 3 to 9 to generate the CSVs from the data you scraped and follow the instructions

# %%
# @title ### Step 1: Alberta Location Selector - RentFaster
from ipywidgets import SelectMultiple, VBox, Label, Layout, Text
import ipywidgets as widgets

# Define your list of options for the multiple select widget
options = [
  'edmonton', 'calgary', 'cochrane', 'red-deer', 'fort-mcmurray',
  'airdrie', 'wetaskiwin', 'lethbridge', 'camrose', 'spruce-grove',
  'okotoks', 'chestermere', 'bonnyville', 'st-albert', 'sylvan-lake',
  'beaumont', 'morinville', 'leduc', 'grande-prairie', 'peace-river',
  'strathmore', 'edson', 'wainwright', 'olds','ponoka'
]

# Create a text widget for displaying selected options
selected_output = Text(
    value='',
    placeholder='Selected options will appear here',
    description='Selected:',
    disabled=False,
    layout=Layout(width='100%')
)

# Event handler function
def on_selection_change(change):
    if change['name'] == 'value':
        # Convert selected options to lowercase and update the text widget
        selected_options = ', '.join([option.lower() for option in change['new']])
        selected_output.value = selected_options

# Create the SelectMultiple widget
location_selector = SelectMultiple(
    options=options,
    value=[],  # No default selection
    description='Locations',
    disabled=False,
    layout=Layout(width='100%', height='200px')  # Adjust layout as needed
)

# Set up the event handler for changes in selection
location_selector.observe(on_selection_change, names='value')

# Instructions on how to select multiple options
instructions = Label('Hold down "Ctrl" (Windows/Linux) or "Cmd" (Mac) to select multiple locations.')

# Group the instructions, the select widget, and the selected output together
vbox = VBox([instructions, location_selector, selected_output])
display(vbox)
# Out:
# VBox(children=(Label(value='Hold down "Ctrl" (Windows/Linux) or "Cmd" (Mac) to select multiple locations.'), S…

# %%
#@title ### Step 2: Get URLs using the URL generator based on your selection
selected_locations = location_selector.value
if not selected_locations:
  print("Please make a selection (at least 1 city) to continue")
else:
  rent_faster_urls = await url_generator(selected_locations,False,True)
# Out:
# Getting listing URLs for edmonton [RentFaster]
# Getting listing URLs for red-deer [RentFaster]
# Getting listing URLs for lethbridge [RentFaster]
# Getting listing URLs for spruce-grove [RentFaster]
# Getting listing URLs for st-albert [RentFaster]
# Getting listing URLs for beaumont [RentFaster]
# URLs retrieved

# %%
#@title ### Step 3: Convert list of URLs into CSV - RentFaster
import ipywidgets as widgets
from IPython.display import display, clear_output

output = widgets.Output()

# Text input widget for the filename
filename_input = widgets.Text(
    value='',
    placeholder='Enter filename here',
    description='Filename:',
    disabled=False
)

# Button to trigger the save action
save_button = widgets.Button(
    description='Save as CSV',
    disabled=False,
    button_style='',
    tooltip='Save your data as a CSV file',
)

# Label for instructions
instructions = widgets.HTML(
    value="If you want to save your data as a CSV run this cell and include the name of the file you want, "
          "please <strong>ONLY use letter and numbers</strong>."
)

def save_to_csv(b):
    with output:
        clear_output(wait=True)
        filename = filename_input.value
        # Validate filename: contains only letters and numbers
        if re.match("^[a-zA-Z0-9]+$", filename):  # Ensure filename is not empty and matches the criteria
            convert_to_csv(rent_faster_urls, f"{filename}.csv")  # Call the function with the provided filename
            print(f"Data saved successfully to {filename}.csv.")
        else:
            print("Error: Filename should only contain letters and numbers and cannot be empty.")

# Set the button click event handler
save_button.on_click(save_to_csv)

# Display the widgets
display(instructions, filename_input, save_button, output)
# Out:
# HTML(value='If you want to save your data as a CSV run this cell and include the name of the file you want, pl…
# Text(value='', description='Filename:', placeholder='Enter filename here')
# Button(description='Save as CSV', style=ButtonStyle(), tooltip='Save your data as a CSV file')
# Output()

# %%
# @title ### Step 4: Range Selector - Kijiji
from ipywidgets import IntRangeSlider, VBox, Button, Output, HTML
from IPython.display import display, clear_output

range_sliders = []  # List to keep track of range sliders
selected_ranges_output = Output()  # Widget to display the selected ranges and generated numbers
generated_numbers = []
# Using HTML widget instead of Label to incorporate line breaks for new lines
description_html = HTML(
    value="This code will help you select the listing numbers you want to retrieve data from Kijiji.<br>"
          "You can select up to 3 ranges from the selector"
          "Once a range has been selected, you would need to click on <strong>'Add New Range'</strong>.<br>"
          "After selecting all your ranges you would need to click on <strong>'Generate Numbers'</strong>. If you want to delete your selection, just clear the output of <strong>THIS CELL</strong> and run it again"
)
def add_range_slider(b=None):
    """Adds a new range slider to the list and updates the display."""
    if len(range_sliders) < 3:  # Limit to 3 range sliders
        new_range_slider = IntRangeSlider(
            value=[1, 10],
            min=1,
            max=190,
            step=1,
            description='Pick a range:',
            disabled=False,
            continuous_update=False,
            orientation='horizontal',
            readout=True
        )
        range_sliders.append(new_range_slider)
        update_display()
    else:
        with selected_ranges_output:
            clear_output(wait=True)  # Clear any previous output messages
            print("Maximum of 3 ranges reached.")

def collect_ranges_and_generate_numbers(b):
    """Collects ranges from sliders, generates numbers within those ranges, and displays the result."""
    with selected_ranges_output:
        clear_output(wait=True)  # Clear the previous output
        all_ranges = [slider.value for slider in range_sliders]
        for r in all_ranges:
            generated_numbers.extend(list(range(r[0], r[1] + 1)))  # Generate numbers within the range
        print("Selected ranges:", ', '.join([f"{r[0]}-{r[1]}" for r in all_ranges]))
        print("Generated numbers:", generated_numbers)

def update_display():
    """Updates the display with all widgets."""
    clear_output(wait=True)  # Clear the previous output including sliders
    display(description_html)  # Display the instructions with HTML for line breaks
    for slider in range_sliders:
        display(slider)
    display(add_range_btn)
    display(collect_ranges_btn)
    display(selected_ranges_output)

# Button to add a new range slider
add_range_btn = Button(description='Add New Range')
add_range_btn.on_click(add_range_slider)

# Button to collect ranges and generate numbers
collect_ranges_btn = Button(description='Generate Numbers')
collect_ranges_btn.on_click(collect_ranges_and_generate_numbers)

# Initial call to add the first range slider and display everything
add_range_slider()

# Initially display the widgets
update_display()
# Out:
# HTML(value="This code will help you select the listing numbers you want to retrieve data from Kijiji.<br>You c…
# IntRangeSlider(value=(1, 10), continuous_update=False, description='Pick a range:', max=190, min=1)
# Button(description='Add New Range', style=ButtonStyle())
# Button(description='Generate Numbers', style=ButtonStyle())
# Output()

# %%
# @title ### Step 5: Get URLs using the URL generator based on your page range selection
# @markdown Now that we have the ranges selected we will scrape the URLs from each page in the listing within the Kijiji website. **Run this cell**

if not generated_numbers:
  print("Please make a selection (at least 1 city) to continue")
else:
  kijiji_urls = await url_generator(generated_numbers,True,False)
# Out:
# Getting listing URLs for AB page 21 [Kijiji]
# Getting listing URLs for AB page 22 [Kijiji]
# Getting listing URLs for AB page 23 [Kijiji]
# Getting listing URLs for AB page 24 [Kijiji]
# Getting listing URLs for AB page 25 [Kijiji]
# Attempt 1 failed with error Page.wait_for_selector: Timeout 6000ms exceeded.
# Call log:
# waiting for locator("ul[data-testid=\"srp-search-list\"]") to be visible
#   -   locator resolved to 2 elements. Proceeding with the first one: <ul class="sc-68931dd3-0 dFkkEs" data-testid="srp-se…>…</ul>
# , retrying...
# Getting listing URLs for AB page 26 [Kijiji]
# Getting listing URLs for AB page 27 [Kijiji]
# Getting listing URLs for AB page 28 [Kijiji]
# Getting listing URLs for AB page 29 [Kijiji]
# Getting listing URLs for AB page 30 [Kijiji]
# Getting listing URLs for AB page 31 [Kijiji]
# Getting listing URLs for AB page 32 [Kijiji]
# URLs retrieved

# %%
# @title ### Step 6: Convert list of URLs into CSV - Kijiji
import ipywidgets as widgets
from IPython.display import display, clear_output
output = widgets.Output()

# Text input widget for the filename
filename_input = widgets.Text(
    value='',
    placeholder='Enter filename here',
    description='Filename:',
    disabled=False
)

# Button to trigger the save action
save_button = widgets.Button(
    description='Save as CSV',
    disabled=False,
    button_style='',
    tooltip='Save your data as a CSV file',
)

# Label for instructions
instructions = widgets.HTML(
    value="If will need to save your URLs data as a CSV, please run this cell and include the name of the file you want, "
          "<strong>ONLY use letter and numbers</strong>."
)

def save_to_csv(b):
    with output:
        clear_output(wait=True)
        filename = filename_input.value
        # Validate filename: contains only letters and numbers
        if re.match("^[a-zA-Z0-9]+$", filename):  # Ensure filename is not empty and matches the criteria
            convert_to_csv(kijiji_urls, f"{filename}.csv")  # Call the function with the provided filename
            print(f"Data saved successfully to {filename}.csv.")
        else:
            print("Error: Filename should only contain letters and numbers and cannot be empty.")

# Set the button click event handler
save_button.on_click(save_to_csv)

# Display the widgets
display(instructions, filename_input, save_button, output)
# Out:
# HTML(value='If will need to save your URLs data as a CSV, please run this cell and include the name of the fil…
# Text(value='', description='Filename:', placeholder='Enter filename here')
# Button(description='Save as CSV', style=ButtonStyle(), tooltip='Save your data as a CSV file')
# Output()

# %% [markdown]
# **Important NOTE**
#
# Because we are dealing with 2 datasets (Kijiji and RentFaster) you will need to perform the following steps in this order:
#
# 1. Select csv with URLs from either Kijiji or RentFaster (Step 7)
# 2. Initialize variables (Step 7.1)
# 3. Perform the scraping on the selected data (Step 8)
# 4. Saved the craped data (Step 9)
#
# After you have done it once for either Kijiji or RentFaster, you will need to do perform the following steps in this order:
#
# 1. Select csv with URLs from either Kijiji or RentFaster (Step 7)
# 2. Perform the scraping on the selected data (Step 8)
# 3. Saved the craped data (Step 9)
#
# **DO NOT PERFORM** step 7.1 again as it will delete your data. Remember to download in your computer the generated CSV files to have a backup!

# %%
# @title ### Step 7: Select CSV and Website
# @markdown Please select the name of the file you have the URLs saved (from Step 6), it should be in CSV format. You also need to select the website of the URLs either Kijiji or RentFaster. After you have made your selection **you need to run this cell**

# @markdown ---
# @markdown #### Enter a file name:
file_name = "urlKijiji.csv" # @param {type:"string"}
# @markdown ---
# @markdown #### Enter the website name:
website = 'kijiji' # @param ["kijiji","rentfaster"]

# %%
# @title ##### Step 7.1: Initialize/Reset global variables
# @markdown Initialize or **Reset** the following variables: `all_property_overviews_kk`, `all_unit_details_kk` for **Kijiji** and `all_property_overviews`, `all_unit_details` for **RentFaster**

# @markdown Run once to create the variables, if you run it again it will reset the variables **Use with caution as you MIGHT LOSS YOUR DATA**
all_property_overviews_kk = {}
all_unit_details_kk = {}
all_property_overviews = {}
all_unit_details = {}

# %%
# @title ### Step 8: Scrape the URLs
# @markdown Execute this cell to Scrape and Parse URLs from CSV you selected on Step 7. The results from the parsing will be saved in the following variables: `all_property_overviews_kk`, `all_unit_details_kk` for **Kijiji** and `all_property_overviews`, `all_unit_details` for **RentFaster**
try:
  await scrape_urls_from_csv(file_name,website)
  back_up_overviews.update(all_property_overviews_kk)
  back_up_overviews.update(all_property_overviews)
  back_up_details.update(all_unit_details)
  back_up_details.update(all_unit_details_kk)
except:
  print("Please run the steps above to select a file name and website")
# Out:
# URLs extracted from the CSV file: urlKijiji.csv. Total URLs to scrape: 552
# Scraping started for https://www.kijiji.ca/v-apartments-condos/edmonton/great-location-in-suite-laundry/1505824661. [1/552]
# Scraped 1 urls out of 552 total.
# Scraping started for https://www.kijiji.ca/v-apartments-condos/edmonton/gorgeous-suites-downtown-edmonton-on-jasper-ave/1679365142. [2/552]
# Scraped 2 urls out of 552 total.
# Scraping started for https://www.kijiji.ca/v-apartments-condos/fort-mcmurray/apartment-for-rent-fort-mcmurray/1639881607. [3/552]
# Scraped 3 urls out of 552 total.
# Scraping started for https://www.kijiji.ca/v-short-term-rental/edmonton/900-furnished-adult-kitchenette-apartment-no-bills/1124123939. [4/552]
# Scraped 4 urls out of 552 total.
# Scraping started for https://www.kijiji.ca/v-apartments-condos/edmonton/2-bedroom-apartment-st-albert-giroux-estates-call-today/1687052836. [5/552]
# Scraped 5 urls out of 552 total.
# Scraping started for https://www.kijiji.ca/v-apartments-condos/lethbridge/downtown-lethbridge-apartment-for-rent-dhillon-tower/1647497843. [6/552]
# Scraped 6 urls out of 552 total.
# Scraping started for https://www.kijiji.ca/v-apartments-condos/edmonton/spacious-4-bed-3-bath-4-level-split-single-family-home-w-doub/1691008921. [7/552]
# Scraped 7 urls out of 552 total.
# Scraping started for https://www.kijiji.ca/v-apartments-condos/lethbridge/affordable-apartments-for-rent-palm-road-apartments-apartmen/1691008679. [8/552]
# Scraped 8 urls out of 552 total.
# Scraping started for https://www.kijiji.ca/v-apartments-condos/edmonton/beautiful-cozy-fully-furnished-1-bdrm-basement-suite/1691016503. [9/552]
# Scraped 9 urls out of 552 total.
# Scraping started for https://www.kijiji.ca/v-apartments-condos/edmonton/great-3-bed-2-5-bath-2-storey-duplex-w-walkout-bsmt-and-an-a/1691008907. [10/552]
# Scraped 10 urls out of 552 total.
# Attempt 1 failed with error Page.goto: Timeout 30000ms exceeded.
# Call log:
# navigating to "https://www.kijiji.ca/v-apartments-condos/edmonton/wonderful-5-bed-home-in-sherwood-park-with-attached-double-garag/1691008906", waiting until "load"
# , retrying...
# Scraping started for https://www.kijiji.ca/v-apartments-condos/edmonton/wonderful-5-bed-home-in-sherwood-park-with-attached-double-garag/1691008906. [11/552]
# Scraped 11 urls out of 552 total.
# Scraping started for https://www.kijiji.ca/v-room-rental-roommate/calgary/cozy-1-bedroom-downtown-cor/1691023120. [12/552]
# Scraped 12 urls out of 552 total.
# Scraping started for https://www.kijiji.ca/v-apartments-condos/lethbridge/for-rent-crowsnestpass/1690755519. [13/552]
# Scraped 13 urls out of 552 total.
# Scraping started for https://www.kijiji.ca/v-apartments-condos/calgary/2-bedrooms-1-bathrooms-basement-suite-for-rent/1691022908. [14/552]
# Scraped 14 urls out of 552 total.
# Scraping started for https://www.kijiji.ca/v-apartments-condos/edmonton/beautiful-4-bed-3-5-bath-home-w-dbl-garage-in-the-community-of/1691008915. [15/552]
# Scraped 15 urls out of 552 total.
# Scraping started for https://www.kijiji.ca/v-apartments-condos/calgary/newer-3-bed-2-5-bath-2-storey-single-family-home-w-a-dbl-attac/1691008909. [16/552]
# Scraped 16 urls out of 552 total.
# Scraping started for https://www.kijiji.ca/v-apartments-condos/edmonton/spacious-1-bed-1-bath-top-floor-apartment-w-an-outdoor-parking/1691008923. [17/552]
# Scraped 17 urls out of 552 total.
# Scraping started for https://www.kijiji.ca/v-apartments-condos/edmonton/great-2-bed-2-5-bath-townhouse-with-a-2-car-attached-tandem-gar/1691008914. [18/552]
# Scraped 18 urls out of 552 total.
# Scraping started for https://www.kijiji.ca/v-short-term-rental/edmonton/condo-for-rent-eagle-rock-grande-cache/1691022608. [19/552]
# Scraped 19 urls out of 552 total.
# Scraping started for https://www.kijiji.ca/v-apartments-condos/calgary/2-bedroom-700-9-st-sw/1691008545. [20/552]
# Scraped 20 urls out of 552 total.
# Scraping started for https://www.kijiji.ca/v-apartments-condos/edmonton/3-bedroom-townhouse-13811-66-st-nw/1691008547. [21/552]
# Scraped 21 urls out of 552 total.
# Scraping started for https://www.kijiji.ca/v-apartments-condos/edmonton/madison-arms-1-bedroom-apartment-for-rent/1691008872. [22/552]
# Scraped 22 urls out of 552 total.
# Scraping started for https://www.kijiji.ca/v-apartments-condos/lethbridge/amazing-2-bed-2-bath-in-gary-station/1691009070. [23/552]
# Scraped 23 urls out of 552 total.
# Scraping started for https://www.kijiji.ca/v-apartments-condos/lethbridge/close-to-the-university-2-bd-ac-suite/1691009084. [24/552]
# Scraped 24 urls out of 552 total.
# Scraping started for https://www.kijiji.ca/v-apartments-condos/edmonton
urls out of 552 total.
# Scraping started for https://www.kijiji.ca/v-apartments-condos/edmonton/affordable-apartments-for-rent-the-rosebrier-apartment-for-r/1690960869. [538/552]
# Scraped 538 urls out of 552 total.
# Scraping started for https://www.kijiji.ca/v-apartments-condos/edmonton/affordable-apartments-for-rent-shannon-villa-apartment-for-r/1690960853. [539/552]
# Scraped 539 urls out of 552 total.
# Scraping started for https://www.kijiji.ca/v-apartments-condos/edmonton/affordable-apartments-for-rent-the-rosebrier-apartment-for-r/1690960670. [540/552]
# Scraped 540 urls out of 552 total.
# Scraping started for https://www.kijiji.ca/v-apartments-condos/edmonton/1-bedroom-premium-10185-115-st-nw-renovated-suite/1690958900. [541/552]
# Scraped 541 urls out of 552 total.
# Scraping started for https://www.kijiji.ca/v-apartments-condos/edmonton/2-bedroom-den-premium-2803-79-st-nw-renovated-suite/1690959348. [542/552]
# Scraped 542 urls out of 552 total.
# Scraping started for https://www.kijiji.ca/v-apartments-condos/calgary/2-bedroom-premium-3524-31-st-nw-renovated-suite/1690959077. [543/552]
# Scraped 543 urls out of 552 total.
# Scraping started for https://www.kijiji.ca/v-commercial-office-space/medicine-hat/commercial-office-and-retail-spaces-for-lease/1672374550. [544/552]
# Scraped 544 urls out of 552 total.
# Scraping started for https://www.kijiji.ca/v-short-term-rental/medicine-hat/fully-furnished-executive-apartment/1674393362. [545/552]
# Scraped 545 urls out of 552 total.
# Scraping started for https://www.kijiji.ca/v-apartments-condos/lethbridge/__two-bedroom-apartment-north-side-for-rent__/1689003921. [546/552]
# Scraped 546 urls out of 552 total.
# Scraping started for https://www.kijiji.ca/v-apartments-condos/fort-mcmurray/217-10218-king-st/1690962611. [547/552]
# Scraped 547 urls out of 552 total.
# Scraping started for https://www.kijiji.ca/v-apartments-condos/fort-mcmurray/311-115-denholm-gate/1690962593. [548/552]
# Scraped 548 urls out of 552 total.
# Scraping started for https://www.kijiji.ca/v-apartments-condos/edmonton/pineview-98-ave-4-bed-2-5-bath-fully-finished-home-garage/1690962644. [549/552]
# Scraped 549 urls out of 552 total.
# Scraping started for https://www.kijiji.ca/v-apartments-condos/edmonton/affordable-apartments-for-rent-forest-apartments-apartment-f/1690960897. [550/552]
# Scraped 550 urls out of 552 total.
# Scraping started for https://www.kijiji.ca/v-apartments-condos/medicine-hat/affordable-apartments-for-rent-eighty-nine-collins-apartments/1690961194. [551/552]
# Scraped 551 urls out of 552 total.
# Scraping started for https://www.kijiji.ca/v-apartments-condos/lloydminster-ab/apartments-for-rent-with-fireplace-glenwood-village-apartmen/1690961261. [552/552]
# Scraped 552 urls out of 552 total.
# Scraping Finished

# %%
# @title ### Step 9: Covert data into DataFrame and saved it as a CSV (10 pts for Kijiji - 10 pts for RentFaster)

# @markdown #### **You will need to perform this twice! Once for Kijiji and Once for RentFaster, your total files will be 4 csv.**
# @markdown ---
# @markdown Now that you have your data, you will need to save it in 2 csv files, each csv file will contain the property_id along with either the overview or the details for that listing. Once you execute this cell I strongly recommend you to download the files generated by accessing them on the left side of your google colab by clicking on the folder icon.

# @markdown ---
# @markdown #### Enter a file name for unit details data (include .csv):

filename_details = "KijijiDetails.csv" # @param {type:"string"}
# @markdown ---
# @markdown #### Enter a file name for property overview data (include .csv):
filename_overview = "KijijiOverview.csv" # @param {type:"string"}
# @markdown #### Enter the website name of the data you want to save:
website = 'kijiji' # @param ["kijiji","rentfaster"]

try:
  if website == 'kijiji':
    convert_kijiji_to_csv(all_unit_details_kk,all_property_overviews_kk,filename_details,filename_overview)
  elif website == 'rentfaster':
    convert_rentfaster_to_csv(all_unit_details,all_property_overviews,filename_details,filename_overview)
  else:
    print("Something went wrong, please check your selections")
except:
  print("Please run all steps above before executing this cell, the data should be generated before reaching this point.")

# %% [markdown]
# ## Part 2: DataFrame, Tables creation and Yelp API setup [Data Management - Total 20 pts]
#
# At this point you should have the data from Step 9 into a CSV. In this part, you are required to convert that data into spark dataframe to perfom on them your data exploration. Remember that you will be working with the raw data from our rental housing scraper, double check ALWAYS your data to better understand what you need to do with it.

# %% [markdown]
# ### Install and set up Pyspark and its associated requirements:
#
# `pyspark` is the Python API for Apache Spark, an open-source, distributed computing system that provides an interface for programming entire clusters with implicit data parallelism and fault tolerance. When dealing with web scraped data from rental listings on RentFaster and Kijiji, `pyspark` enables efficient data processing and analysis at scale. Here's how it contributes to our project:
#
# - **Data Exploration**: `pyspark` allows for comprehensive data exploration, including summarizing datasets, querying specific information (e.g., average rental prices, most common amenities), and identifying trends within the rental market of Alberta, Canada.
#
# - **Data Transformation**: The data scraped from these websites often requires cleaning and transformation to be useful for analysis. `pyspark` provides a wide array of functions for data manipulation, such as filtering, grouping, and aggregating data. This is essential for preparing the web scraped data, which may include varying formats, missing values, or irrelevant information, into a structured and analysis-ready format.
#
# `findspark` is a helper library designed to make it easier to find and start using Apache Spark's `pyspark` within Python applications. Essentially, it simplifies the process of initializing Spark in Python scripts by locating the Spark installation (which can sometimes be a challenge due to environment variables and path configurations).
#
# - **Seamless Integration**: By using `findspark`, you can more easily integrate Apache Spark into your Python environment for web scraping projects. It ensures that `pyspark` can be imported and used in your scripts as any other Python library, without the need for cumbersome setup processes or environment configuration. This is particularly useful in educational or experimental projects where simplifying the setup process can save valuable time and effort.

# %%
 # !pip install pyspark
 # !pip install findspark
# Out:
# Collecting pyspark
#   Downloading pyspark-3.5.1.tar.gz (317.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.0/317.0 MB 3.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.10/dist-packages (from pyspark) (0.10.9.7)
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.5.1-py2.py3-none-any.whl size=317488491 sha256=e083c8bf7e668570a83de582ee182afc6d31c036046edba8775156c647829c87
#   Stored in directory: /root/.cache/pip/wheels/80/1d/60/2c256ed38dddce2fdd93be545214a63e02fbd8d74fb0b7f3a6
# Successfully built pyspark
# Installing collected packages: pyspark
# Successfully installed pyspark-3.5.1
# Collecting findspark
#   Downloading findspark-2.0.1-py2.py3-none-any.whl (4.4 kB)
# Installing collected packages: findspark
# Successfully installed findspark-2.0.1

# %% [markdown]
# ### Spark Libraries Explained
#
# - **`os`**: This is a standard Python library that provides a way to interact with the operating system. `os` is used to perform operations like navigating the file system, changing and retrieving directory information, managing files, and accessing environment variables.
#
# - **`findspark`**: A utility library designed to make it easier to find and connect to an Apache Spark installation from Python applications. When working with Spark, setting up environment variables and paths correctly is important to successfully starting a Spark session. `findspark` simplifies this process by automatically locating the Spark installation on your system and setting the required environment variables, eliminating the need for manual configuration.
#
# - **`findspark.init()`**: This function call is used to initialize Spark in the Python script. It must be called before importing and using `pyspark`, as it sets up the environment by locating the Spark installation and setting the necessary environment variables. This step ensures that `pyspark` can be imported without issues related to finding the Spark installation.
#
# - **`pyspark`**: The Python API for Apache Spark, `pyspark` allows Python programmers to interface with Spark's distributed data processing capabilities. By importing `pyspark`, you gain access to Spark's core functionalities, including creating RDDs (Resilient Distributed Datasets), transformations, and actions on these datasets, enabling large-scale data processing.
#
# - **`from pyspark.sql import SparkSession`**: SparkSession is the entry point to programming Spark with the Dataset and DataFrame API. A SparkSession can be used to create DataFrame objects, register DataFrame as tables, execute SQL queries, and read data from an external source. Importing SparkSession is essential for working with Spark SQL and DataFrame operations, which are powerful tools for data analysis, especially when dealing with structured data like that obtained from web scraping.

# %%
import os
import findspark
findspark.init()
# only run after findspark.init()
import pyspark
from pyspark.sql import SparkSession

# %% [markdown]
# ### Step 1: Initializing a spark cluster (5 pts)
#
# Include your code below to initialize the spark cluster and add a verification step as well. Use a meaninful name for the PySpark App Name

# %%
#Your code goes here
my_spark = SparkSession.builder.appName('Final_project_DBMS').getOrCreate()

# %% [markdown]
# Verification step

# %%
#Your code goes here
df_check = my_spark.sql('''select 'spark' as hello''')
df_check.show()
# Out:
# +-----+
# |hello|
# +-----+
# |spark|
# +-----+

# %% [markdown]
# ### Step 2: Create dataframes for analytics [Total of 15 pts]
#
# Create the PySpark dataframe with the csv data you got from Part 1 - Step 9. Remember that you can always check your files on the left folder icon within your google colab. You can use the following link to get an idea on how to do it: https://spark.apache.org/docs/latest/sql-data-sources-csv.html
#
# **Tips:**
#
# *   You should create a independent dataframe for each csv, use meaninful names!
# *   The CSV can contain newlines, to parse it you would need to consider using the "multiLine" option for `spark.read`
# *   By default headers are not including, but you need to include them! Look for the option to accomplish this
# *   Remember to use the `<your-PySparDF>.show(truncate=False)` to see how your data is looking!
# *   Check your practice Lab6 on how yo create your headers and parameters to get data from the API

# %% [markdown]
# Step 2.1: Create PySpark dataframes **Kijiji** (5 pts)

# %%
#Your code goes here
df_details_k = my_spark.read.option("multiline", True).option("header", True).csv('KijijiDetails.csv')
df_overview_k = my_spark.read.option("multiline", True).option("header", True).csv('KijijiOverview.csv')
df_overview_k.show(truncate=False)
# Out:
# +----------+------------------------------------------------------------------------------------------------------------------------------+-------------------------+----------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |unit_id   |listing_url                                                                                                                   |date_posted              |address                                                                                                                                       |price_info                                 |description                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |
# +----------+------------------------------------------------------------------------------------------------------------------------------+-------------------------+----------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |1505824661|https://www.kijiji.ca/v-apartments-condos/edmonton/great-location-in-suite-laundry/1505824661                                 |Posted 2 days ago        |{'address_1': '10 Woodsmere Close, Fort Saskatchewan, AB, T8L 4N9', 'address_2': '10 Woodsmere Close, Fort Saskatchewan, AB, T8L 4N9'}        |{'amt': 125000, 'cur': 'CAD', 't': 'FIXED'}|PET FRIENDLY  INSUITE LAUNDRY  5 APPLIANCES WITH DISWASHER  POWERED PARKING STALLS10 Woodsmere Close Fort Saskatchewan AB T8L 4N9httpwwwwoodsmereca7809929222GREAT LOCATION Adjacent to Tim Hortons several neighboring gas stations and convenience stores including Husky Shell and 7Eleven Close to the DOW Centennial Centre where residents skate and take on many other sporting activities and the new football stadium Taurus FieldSUITES INCLUDE5 full size AppliancesIn suite laundrySpacious kitchenWindow coverings throughoutOne powered parking stallHeat and waterPrivate balconySecure access to buildingCLIENT RESPONSIBILITIESPower telephone cable internetAdditional parking is 50month per stall subject to availabilityRatesPrices are subject to change without notice                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                |
# |1679365142|https://www.kijiji.ca/v-apartments-condos/edmonton/gorgeous-suites-downtown-edmonton-on-jasper-ave/1679365142                 |Posted 15 days ago       |{'address_1': '9925 Jasper Avenue, Edmonton, AB, T5J 2X5', 'address_2': '9925 Jasper Avenue, Edmonton, AB, T5J 2X5'}                          |{'amt': 150000, 'cur': 'CAD', 't': 'FIXED'}|99 Jasper  Downtown smokefree rental apartmentsCall Today25 OFF ANY TELUS OPTIK TV AND INTERNET PRODUCT MONTHLY12
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            |
# +----------+------------------------------------------------------------------------------------------------------------------------------+-------------------------+----------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 20 rows

# %% [markdown]
# Step 2.2: Create PySpark dataframes **RentFaster** (5 pts)

# %%
# Your code goes here
df_details_r = my_spark.read.option("multiline", True).option("header", True).csv('RentFasterDetails (1).csv')
df_overview_r = my_spark.read.option("multiline", True).option("header", True).csv('RentFasterOverview (1).csv')
df_overview_r.show(truncate=False)
# Out:
# +-----------+------+-----------------+-------------------------------+-----------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------+--------------+----------+---------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |property_id|id    |location         |name                           |url                                                                                                  |slogan                                                                                                                  |priceRange    |telephone |image                                                                                                                                  |description                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# +-----------+------+-----------------+-------------------------------+-----------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------+--------------+----------+---------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |554875     |554875|/ab/edmonton     |The Willow                     |https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/queen-mary-park/pet-friendly/554875|Get 1-month FREE rent plus choose between 3 months FREE parking or 3 months FREE utilities, and receive a $300 prepaid g|$1,540 - 1,555|5874140077|https://f1a3d4fea3a9a877e732-356deb4d9644d2835b7712e712dbd1ea.ssl.cf2.rackcdn.com/554875/9858713.v.2cad9fae4e26dbe9c29fd24f98597c93.jpg|Discover The Willow  NEW luxury petfriendly apartment rentals centrally located in Queen Mary Park EdmontonTake advantage of our April offer One month rentfree on a 13month lease Plus choose between three months of complimentary parking or utilitiesAct now as our units are filling up fast  were already 90 leasedEmbrace a refined lifestyle amidst urban parks and conveniences Select from our array of suites including onebedroom twobedroom twobedroom plus den layouts and threebedroom townhomes Each unit is meticulously crafted for modern living with premium finishes like luxury vinyl plank flooring 9foot ceilings contemporary lighting air conditioning insuite laundry energysaving green features and a private terrace or balcony At The Willow an abundance of amenities awaits from a social room and fitness center to a sprawling rooftop terrace bike room and pet washWe also welcome dogs of all breeds and sizesBeing minutes from both downtown Edmonton and the river valley helps you balance city life while still getting away from it all We are situated minutes from MacEwan University NAIT Royal Alexandra Hospital and 124thStreetfor all your essential needsDont miss out on securing your new home at The Willow  contact our leasing team today at 5879903812Current IncentivesA choice of 3 months free utilities OR 3 months free parkingWelcome basket including 300 prepaid VISAMove in up to a week early at no chargeAdditionalVideo surveillanceIndividual thermostatsWalkin closetsCable readySchools nearbyInternet readyRooftop BBQ AreaPetBike wash                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         ...
# |540024     |540024|/ab/edmonton     |The Legacy at Griesbach        |https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/griesbach/pet-friendly/540024      |The Legacy at Griesbach                                                                                                 |$1,665 - 1,695|5874001246|https://f1a3d4fea3a9a877e732-356deb4d9644d2835b7712e712dbd1ea.ssl.cf2.rackcdn.com/540024/9440063.v.f64d94f3d6e1f1587d230881bc25dffc.jpg|AdditionalEnsuite bathroomWalkin closetsSchools nearbyWalking trailsITBusiness centre Basketball courtCommunity barbequesElectric vehicle charging stations247 customer careQuartz countertopsEvent space with kitchenStainless steel appliancesPackage locker roomNew propertyPetfriendly pet restrictions applyHighgloss cabinetsSoftclose cabinetry                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ...
or Resident Lounge featuring fireplace soft seating areas and a private diningmeeting room Fullyequipped Fitness Centre with convertible yogaworkout studio perfect for yoga HIIT or group fitness Three fullsize elevators Parcel delivery lockers Heated underground parkade and Captivating Capital City Living is yours to experience at Augustana Contact our leasing team todayVideo surveillanceUnderground parkingElevatorsSocial roomFitness roomStorage lockersBicycle roomWheelchair AccessAir conditionerFridgeStoveWasher in suiteDishwasher availableBalconiesCity viewsDryer in suiteExercise roomRecreation roomPublic transitShopping nearbyParks nearbySchools nearbyNo Smoking allowedBalconies with Panoramic Views of the CityParty RoomFitness Fully Equipped Gym and Yoga RoomBBQ PatioPet FriendlyCommon Area Patio River ViewsDowntown EdmontonElevators Indoor ParkingBalconyCoworking amp study spaceGames amp billiards roomRooftop BBQ AreaVinyl Plank FloorsRiver Valley MacEwan University Alberta Legislature GroundsAirConditioningSocial RoomAdditionalVideo surveillanceSchools nearbyFitness Fully Equipped Gym and Yoga RoomBBQ PatioCommon Area PatioDowntown EdmontonCoworking amp study spaceGames amp billiards roomRooftop BBQ AreaRiver ValleyMacEwan UniversityAlberta Legislature GroundsAirConditioning                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ...
# |532440     |532440|/ab/edmonton     |Crawford CoLiv Student Housing |https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/strathcona/furnished/532440        |Affordable Student Living                                                                                               |$800 - 800    |5876354981|https://f1a3d4fea3a9a877e732-356deb4d9644d2835b7712e712dbd1ea.ssl.cf2.rackcdn.com/532440/9057224.v.2cb6cd417173da6d76780e6819a91e9a.jpg|ATTENTION STUDENTSPlease reply to advertisement with the school and program you are enrolled inBrand NEW space only minutes from the University of Alberta with direct access to an arterial bike lane ride sharing services and public transit Be among the FIRST to live in this newly renovated historic building only steps from the Old Strathcona Farmers Market cafes bars and restaurantsCrawford CoLiv is a coliving concept with access to a common kitchen washrooms and living area Its the perfect model of living for students and people working in the neighbourhood Allinclusive pricing 800month includesAll utilities heat water powerAll kitchen utensils plates pots and pans  we provide everything you needSpacious commercial fridge and freezerBlazingfast internetAll cleaning supplies are providedWeekly professional cleaningof the common areasSorry no petsRefer a friend and get 400 off your rent for one month offer valid for one referralContact us today for a tourhttpswwwcolivca                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   ...
# +-----------+------+-----------------+-------------------------------+-----------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------+--------------+----------+---------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# only showing top 20 rows

# %% [markdown]
# Step 2.3: Create Yelp Fusion API **parameters** and **headers** (5 pts)
#
# To begin, the first step is to create a Yelp Developer account, which you can accomplish by clicking [here](https://www.yelp.com/developers). After setting up your account, head to the Yelp Fusion API section on the Yelp Developer page and select 'Get Started.' This action will grant you access to API keys that are essential for fetching restaurant data, allowing you to perform queries based on addresses extracted from your rental listings. By integrating Yelp Fusion data with our scraped rental information, we can provide a comprehensive view of each listing's neighborhood amenities, enhancing the value of our dataset with actionable insights for potential renters.

# %%
# Your code goes here
import requests
api_key = '8eqjzK3BpkTDsYgV_Iatj5LPlJLfco7sTo-i31B0x2VrE4hSOuBSrO79fOY1V6sUAQa6q6zl1epiuxKcGjarWOx7KfkflMos1f7gcLbz5-XZDMsuSgzGxYwZbH8eZnYx'
endpoint_url = 'https://api.yelp.com/v3/businesses/search'
headers = {
    'Authorization': f'Bearer {api_key}',
}

params = {
    'term':'restaurants',
    'location': 'Edmonton',
    'limit' : 50
}

# %%
import csv
my_response = requests.get(endpoint_url, headers = headers, params = params)
yelp_data = my_response.json()
yelp_data
# Out:
# {'businesses': [{'id': 'gtXAx_G5j6K1TmuJ2v5Rbg',
#    'alias': 'rge-rd-edmonton',
#    'name': 'RGE RD',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Br_RNNJuBFsjMiDqaWt3LA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rge-rd-edmonton?adjust_creative=2tv7N4jCygDlUszgzmAOfg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2tv7N4jCygDlUszgzmAOfg',
#    'review_count': 179,
#    'categories': [{'alias': 'newcanadian', 'title': 'Canadian (New)'}],
#    'rating': 4.4,
#    'coordinates': {'latitude': 53.5507814, 'longitude': -113.5338044},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '10643 - 123 Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Edmonton',
#     'zip_code': 'T5M 1Z1',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['10643 - 123 Street',
#      'Edmonton, AB T5M 1Z1',
#      'Canada']},
#    'phone': '+17804474577',
#    'display_phone': '+1 780-447-4577',
#    'distance': 2927.754958615857},
#   {'id': '3koeM2Blt-4rEmVIJAZf8Q',
#    'alias': 'woodwork-edmonton',
#    'name': 'Woodwork',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/XHIpmhR3bR6RuSfIXoqnMQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/woodwork-edmonton?adjust_creative=2tv7N4jCygDlUszgzmAOfg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2tv7N4jCygDlUszgzmAOfg',
#    'review_count': 175,
#    'categories': [{'alias': 'newcanadian', 'title': 'Canadian (New)'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.2,
#    'coordinates': {'latitude': 53.5419431693898,
#     'longitude': -113.490731079867},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '10132-100 Street',
#     'address2': None,
#     'address3': '',
#     'city': 'Edmonton',
#     'zip_code': 'T5J 0N8',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['10132-100 Street', 'Edmonton, AB T5J 0N8', 'Canada']},
#    'phone': '+17807574100',
#    'display_phone': '+1 780-757-4100',
#    'distance': 1912.993215405463},
#   {'id': '3YVNzWtVSfb7q9iBqmhVpw',
#    'alias': 'la-boca-loca-edmonton',
#    'name': 'La Boca Loca',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/yg-7uiuw-8sf1lRKtI5g3w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-boca-loca-edmonton?adjust_creative=2tv7N4jCygDlUszgzmAOfg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2tv7N4jCygDlUszgzmAOfg',
#    'review_count': 12,
#    'categories': [{'alias': 'latin', 'title': 'Latin American'}],
#    'rating': 4.7,
#    'coordinates': {'latitude': 53.47444, 'longitude': -113.48575},
#    'transactions': [],
#    'location': {'address1': '3903 99 Street',
#     'address2': 'Suite 120',
#     'address3': None,
#     'city': 'Edmonton',
#     'zip_code': 'T6E 6M2',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['3903 99 Street',
#      'Suite 120',
#      'Edmonton, AB T6E 6M2',
#      'Canada']},
#    'phone': '+17804633233',
#    'display_phone': '+1 780-463-3233',
#    'distance': 6250.698733418835},
#   {'id': '00uLQHBVirvmfv4pGlIBGA',
#    'alias': 'baobao-edmonton',
#    'name': 'BaoBao',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/wuzlhZq75S-Yb9aartvWUQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/baobao-edmonton?adjust_creative=2tv7N4jCygDlUszgzmAOfg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2tv7N4jCygDlUszgzmAOfg',
#    'review_count': 43,
#    'categories': [{'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'dumplings', 'title': 'Dumplings'}],
#    'rating': 4.3,
#    'coordinates': {'latitude': 53.54136, 'longitude': -113.50214},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '10544 Jasper Avenue',
#     'address2': '',
#     'address3': '',
#     'city': 'Edmonton',
#     'zip_code': 'T5J 1Z7',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['10544 Jasper Avenue',
#      'Edmonton, AB T5J 1Z7',
#      'Canada']},
#    'phone': '+15875235747',
#    'display_phone': '+1 587-523-5747',
#    'distance': 1476.8825258446152},
#   {'id': '2pj5byDMoMDu-d0bTu2Sew',
#    'alias': 'pip-edmonton',
#    'name': 'Pip',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/d-_0AYgJxVIEg0FhVVBcig/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pip-edmonton?adjust_creative=2tv7N4jCygDlUszgzmAOfg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2tv7N4jCygDlUszgzmAOfg',
#    'review_count': 193,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'comfortfood', 'title': 'Comfort Food'}],
#    'rating': 4.3,
#    'coordinates': {'latitude': 53.5189807, 'longitude': -113.4971429},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '10335 83 Avenue NW',
#     'address2': '',
#     'address3': None,
#     'city': 'Edmonton',
#     'zip_code': 'T6E 2C6',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['10335 83 Avenue NW',
#      'Edmonton, AB T6E 2C6',
#      'Canada']},
#    'phone': '+17807604747',
#    'display_phone': '+1 780-760-4747',
#    'distance': 1360.189992403652},
#   {'id': 'l7DhJNwumsbDK9cuusE9sQ',
#    'alias': 'bundok-edmonton-3',
#    'name': 'Bundok',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/39692OqhRjCeWhdCFwfssA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bundok-edmonton-3?adjust_creative=2tv7N4jCygDlUszgzmAOfg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2tv7N4jCygDlUszgzmAOfg',
#    'review_count': 55,
#    'categories': [{'alias': 'newcanadian', 'title': 'Canadian (New)'}],
#    'rating': 4.4,
#    'coordinates': {'latitude': 53.54366, 'longitude': -113.4994049},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '10228 104 Street NW',
#     'address2': '',
#     'address3': None,
#     'city': 'Edmonton',
#     'zip_code': 'T5J 1B8',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['10228 104 Street NW',
#      'Edmonton, AB T5J 1B8',
#      'Canada']},
#    'phone': '+17804200192',
#    'display_phone': '+1 780-420-0192',
#    'distance': 1782.3809881189493},
#   {'id': '8mmS0Krqc1PTOnl5TCdGbg',
#    'alias': 'lotus-house-of-kebab-edmonton',
#    'name': 'Lotus House of Kebab',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0YmsN541hiJ1k_yplOPc9A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lotus-house-of-kebab-edmonton?adjust_creative=2tv7N4jCygDlUszgzmAOfg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2tv7N4jCygDlUszgzmAOfg',
#    'review_count': 1,
#    'categories': [{'alias': 'kebab', 'title': 'Kebab'},
#     {'alias': 'persian', 'title': 'Persian/Iranian'},
#     {'alias': 'halal', 'title': 'Halal'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 53.5179178, 'longitude': -113.4893833},
#    'transactions': [],
#    'location': {'address1': '10013 82 Avenue NW',
#     'address2': None,
#     'address3': '',
#     'city': 'Edmonton',
#     'zip_code': 'T6E 1Z2',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['10013 82 Avenue NW',
#      'Edmonton, AB T6E 1Z2',
#      'Canada']},
#    'phone': '+14389909380',
#    'display_phone': '+1 438-990-9380',
#    'distance': 1793.952314604856},
#   {'id': 'LDPrW1OI0YA2ppITnbUFng',
#    'alias': 'rosewood-foods-edmonton',
#    'name': 'Rosewood Foods',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/IWNZpe5gibwA-1rmbrcs1w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rosewood-foods-edmonton?adjust_creative=2tv7N4jCygDlUszgzmAOfg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2tv7N4jCygDlUszgzmAOfg',
#    'review_count': 19,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 4.6,
#    'coordinates': {'latitude': 53.5424329438608, 'longitude': -113.4909425},
#    'transactions': [],
#    'location': {'address1': '101-10150 100 Street NW',
#     'address2': '',
#     'address3': None,
#     'city': 'Edmonton',
#     'zip_code': 'T5J 0P6',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['101-10150 100 Street NW',
#      'Edmonton, AB T5J 0P6',
#      'Canada']},
#    'phone': '+17807578030',
#    'display_phone': '+1 780-757-8030',
#    'distance': 1946.1141324953715},
#   {'id': 'FgLO3jQX1XjaqILsG3nN1Q',
#    'alias': 'flat-boy-burgers-edmonton',
#    'name': 'Flat Boy Burgers',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/tW6cWkEeZenfHSum3nsvQA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/flat-boy-burgers-edmonton?adjust_creative=2tv7N4jCygDlUszgzmAOfg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2tv7N4jCygDlUszgzmAOfg',
#    'review_count': 12,
#    'categories': [{'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.8,
#    'coordinates': {'latitude': 53.52239294098521,
#     'longitude': -113.5066153862915},
#    'transactions': [],
#    'location': {'address1': '8620 107 ST NW',
#     'address2': 'Inside The Granite Curling Club',
#     'address3': 'Granite Curling Club',
#     'city': 'Edmonton',
#     'zip_code': 'T3A 2G8',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['8620 107 ST NW',
#      'Inside The Granite Curling Club',
#      'Granite Curling Club',
#      'Edmonton, AB T3A 2G8',
#      'Canada']},
#    'phone': '+14166188296',
#    'display_phone': '+1 416-618-8296',
#    'distance': 736.1241247535619},
#   {'id': 'lPPYZr1_jx0XeW-xR9WJtw',
#    'alias': 'dosc-edmonton',
#    'name': 'DOSC',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/d08xhGLEgbd_5Vw13ZhBXA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dosc-edmonton?adjust_creative=2tv7N4jCygDlUszgzmAOfg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2tv7N4jCygDlUszgzmAOfg',
#    'review_count': 119,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'steak', 'title': 'Steakhouses'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 53.5428720872819,
#     'longitude': -113.499512283622},
#    'transactions': [],
#    'location': {'address1': '10190 - 104 Street NW',
#     'address2': 'Main Floor',
#     'address3': None,
#     'city': 'Edmonton',
#     'zip_code': 'T5J 1A7',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['10190 - 104 Street NW',
#      'Main Floor',
#      'Edmonton, AB T5J 1A7',
#      'Canada']},
#    'phone': '+17805400606',
#    'display_phone': '+1 780-540-0606',
#    'distance': 1695.8891469010546},
#   {'id': 'O6MIsYsonX88nSFi_rkJOw',
#    'alias': 'hathaways-diner-edmonton',
#    'name': "Hathaway's Diner",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Ew7d-JjiUZbPR0pL_SXCcw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hathaways-diner-edmonton?adjust_creative=2tv7N4jCygDlUszgzmAOfg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2tv7N4jCygDlUszgzmAOfg',
#    'review_count': 123,
#    'categories': [{'alias': 'diners', 'title': 'Diners'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 53.59283677654092,
#     'longitude': -113.54850976566294},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '13225-132 Street NW',
#     'address2': '',
#     'address3': '',
#     'city': 'Edmonton',
#     'zip_code': 'T5L 1R9',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['13225-132 Street NW',
#      'Edmonton, AB T5L 1R9',
#      'Canada']},
#    'phone': '+17804885989',
#    'display_phone': '+1 780-488-5989',
#    'distance': 7574.231539495103},
#   {'id': 'dFTaHC6bn2mdYdGLUkdq1g',
#    'alias': 'the-butternut-tree-edmonton',
#    'name': 'The Butternut Tree',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/d2hFprwPO8wbFCtRrL_-OQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-butternut-tree-edmonton?adjust_creative=2tv7N4jCygDlUszgzmAOfg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2tv7N4jCygDlUszgzmAOfg',
#    'review_count': 44,
#    'categories': [{'alias': 'newcanadian', 'title': 'Canadian (New)'}],
#    'rating': 4.3,
#    'coordinates': {'latitude': 53.53431, 'longitude': -113.50977},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '9707 110 St NW',
#     'address2': '',
#     'address3': None,
#     'city': 'Edmonton',
#     'zip_code': 'T5K 2L9',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['9707 110 St NW', 'Edmonton, AB T5K 2L9', 'Canada']},
#    'phone': '+17807602271',
#    'display_phone': '+1 780-760-2271',
#    'distance': 613.7504258681192},
#   {'id': 'qoD6-nDDfEuNPRJipJxpOA',
#    'alias': 'oeb-breakfast-edmonton-4',
#    'name': 'OEB Breakfast',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/OAwa2JhwInGmkEBXRMzUfw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/oeb-breakfast-edmonton-4?adjust_creative=2tv7N4jCygDlUszgzmAOfg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2tv7N4jCygDlUszgzmAOfg',
#    'review_count': 250,
#    'categories': [{'alias': 'breakfast_brunch',
#      'title': 'Breakfast & Brunch'}],
#    'rating': 4.4,
#    'coordinates': {'latitude': 53.542609, 'longitude': -113.492594},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '10174 100A Street',
#     'address2': None,
#     'address3': '',
#     'city': 'Edmonton',
#     'zip_code': 'T5J 0H3',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['10174 100A Street',
#      'Edmonton, AB T5J 0H3',
#      'Canada']},
#    'phone': '+15875200936',
#    'display_phone': '+1 587-520-0936',
#    'distance': 1896.984932783772},
#   {'id': 'sVwbevTHJK6SmZxBIHzm5g',
#    'alias': 'campiō-brewing-co-edmonton',
#    'name': 'Campiō Brewing Co',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/RhK0KAWH1gGVCgpcm3eP_w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/campi%C5%8D-brewing-co-edmonton?adjust_creative=2tv7N4jCygDlUszgzmAOfg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2tv7N4jCygDlUszgzmAOfg',
#    'review_count': 48,
#    'categories': [{'alias': 'tradamerican', 'title': 'American'},
#     {'alias': 'breweries', 'title': 'Breweries'}],
#    'rating': 4.3,
#    'coordinates': {'latitude': 53.54431, 'longitude': -113.5007},
#    'transactions': [],
#    'location': {'address1': '10257 105 Street NW',
#     'address2': '',
#     'address3': None,
#     'city': 'Edmonton',
#     'zip_code': 'T5J 1E3',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['10257 105 Street NW',
#      'Edmonton, AB T5J 1E3',
#      'Canada']},
#    'phone': '+15876351952',
#    'display_phone': '+1 587-635-1952',
#    'distance': 1818.073377950545},
#   {'id': '2f9zoxMg6hmonYNR6zxBDw',
#    'alias': 'dogpatch-edmonton',
#    'name': 'Dogpatch',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/1LxwG3RbreNbLMMtHHgyZg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dogpatch-edmonton?adjust_creative=2tv7N4jCygDlUszgzmAOfg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2tv7N4jCygDlUszgzmAOfg',
#    'review_count': 26,
#    'categories': [{'alias': 'bistros', 'title': 'Bistros'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 53.54468327770364,
#     'longitude': -113.47114641219376},
#    'transactions': [],
#    'location': {'address1': '10158 90 Street NW',
#     'address2': '',
#     'address3': None,
#     'city': 'Edmonton',
#     'zip_code': 'T5H 1R7',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['10158 90 Street NW',
#      'Edmonton, AB T5H 1R7',
#      'Canada']},
#    'phone': '+17807618700',
#    'display_phone': '+1 780-761-8700',
#    'distance': 3084.347574673002},
#   {'id': 'oO1BUhSRwHIrnULwb_XIjQ',
#    'alias': 'la-petite-iza-edmonton',
#    'name': 'La Petite Iza',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9klgriKUEh-Q9pnZ9xi6UA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-petite-iza-edmonton?adjust_creative=2tv7N4jCygDlUszgzmAOfg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2tv7N4jCygDlUszgzmAOfg',
#    'review_count': 25,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'bistros', 'title': 'Bistros'}],
#    'rating': 4.4,
#    'coordinates': {'latitude': 53.523992, 'longitude': -113.513261},
#    'transactions': [],
#    'location': {'address1': '10926 88 Avenue NW',
#     'address2': 'Floor 3',
#     'address3': None,
#     'city': 'Edmonton',
#     'zip_code': 'T6G 0Z1',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['10926 88 Avenue NW',
#      'Floor 3',
#      'Edmonton, AB T6G 0Z1',
#      'Canada']},
#    'phone': '+17804350083',
#    'display_phone': '+1 780-435-0083',
#    'distance': 589.4147204018122},
#   {'id': 'lJ7eghiuciw-qGmfydY7tQ',
#    'alias': 'izakaya-tomo-edmonton',
#    'name': 'Izakaya Tomo',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/OeWu1HqvoD_dYRHG4jW1Kw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/izakaya-tomo-edmonton?adjust_creative=2tv7N4jCygDlUszgzmAOfg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2tv7N4jCygDlUszgzmAOfg',
#    'review_count': 172,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.4,
#    'coordinates': {'latitude': 53.4713891663463,
#     'longitude': -113.485274612904},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '3739 99 Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Edmonton',
#     'zip_code': 'T6E 6J7',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['3739 99 Street', 'Edmonton, AB T6E 6J7', 'Canada']},
#    'phone': '+17804409152',
#    'display_phone': '+1 780-440-9152',
#    'distance': 6580.483952548397},
#   {'id': 'fM6XQeGW70a4EFbjqAAy3Q',
#    'alias': 'sugarbowl-edmonton',
#    'name': 'SugarBowl',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/jhvvMxCKEgPhJn-aNY_UwA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sugarbowl-edmonton?adjust_creative=2tv7N4jCygDlUszgzmAOfg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2tv7N4jCygDlUszgzmAOfg',
#    'review_count': 493,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'comfortfood', 'title': 'Comfort Food'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 53.5239312527495, 'longitude': -113.513113},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '10922 88 Avenue NW',
#     'address2': '',
#     'address3': '',
#     'city': 'Edmonton',
#     'zip_code': 'T6G 0Z1',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['10922 88 Avenue NW',
#      'Edmonton, AB T6G 0Z1',
#      'Canada']},
#    'phone': '+17804338369',
#    'display_phone': '+1 780-433-8369',
#    'distance': 594.2014026675109},
#   {'id': 'FS9rhElLqRC04kKyPam8FA',
#    'alias': 'bodega-124th-street-edmonton',
#    'name': 'Bodega 124th Street',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/1uMJB8nNqSsc4ILZ-zdxbw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bodega-124th-street-edmonton?adjust_creative=2tv7N4jCygDlUszgzmAOfg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2tv7N4jCygDlUszgzmAOfg',
#    'review_count': 32,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.3,
#    'coordinates': {'latitude': 53.5469099, 'longitude': -113.53689},
#    'transactions': [],
#    'location': {'address1': '12417 Stony Plain Road',
#     'address2': '',
#     'address3': None,
#     'city': 'Edmonton',
#     'zip_code': 'T5N 3N3',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['12417 Stony Plain Road',
#      'Edmonton, AB T5N 3N3',
#      'Canada']},
#    'phone': '+17802506066',
#    'display_phone': '+1 780-250-6066',
#    'distance': 2711.394645466731},
#   {'id': 'n4z30-wLC1WYW6SDSDAdRA',
#    'alias': 'bianco-edmonton',
#    'name': 'Bianco',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/nhS9MVJqfO1-GDm9Hvl1KQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bianco-edmonton?adjust_creative=2tv7N4jCygDlUszgzmAOfg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2tv7N4jCygDlUszgzmAOfg',
#    'review_count': 58,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 53.5424557443708,
#     'longitude': -113.49200528115},
#    'transactions': [],
#    'location': {'address1': '120-10020 101 A Avenue',
#     'address2': '',
#     'address3': None,
#     'city': 'Edmonton',
#     'zip_code': 'T5J 3G2',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['120-10020 101 A Avenue',
#      'Edmonton, AB T5J 3G2',
#      'Canada']},
#    'phone': '+17807618838',
#    'display_phone': '+1 780-761-8838',
#    'distance': 1904.871983653411},
#   {'id': 'k9nDoJ0MaMYymI-iceql-A',
#    'alias': 'rockin-robyns-diner-edmonton',
#    'name': "Rockin' Robyn's Diner",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/nK_mcWEWmA6VV2Pi3XwFdQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rockin-robyns-diner-edmonton?adjust_creative=2tv7N4jCygDlUszgzmAOfg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2tv7N4jCygDlUszgzmAOfg',
#    'review_count': 186,
#    'categories': [{'alias': 'breakfast_brunch',
#      'title': 'Breakfast & Brunch'}],
#    'rating': 4.2,
#    'coordinates': {'latitude': 53.55643, 'longitude': -113.60692},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '16604- 109 Avenue',
#     'address2': '',
#     'address3': '',
#     'city': 'Edmonton',
#     'zip_code': 'T5P 1C2',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['16604- 109 Avenue',
#      'Edmonton, AB T5P 1C2',
#      'Canada']},
#    'phone': '+17807565656',
#    'display_phone': '+1 780-756-5656',
#    'distance': 7063.345471227296},
#   {'id': '36F6K3PGGV2ICZBNDoh0wg',
#    'alias': 'baijiu-edmonton',
#    'name': 'Baijiu',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/GlJ1I-FBRASUV26yqDbQqg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/baijiu-edmonton?adjust_creative=2tv7N4jCygDlUszgzmAOfg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2tv7N4jCygDlUszgzmAOfg',
#    'review_count': 57,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.4,
#    'coordinates': {'latitude': 53.5459076, 'longitude': -113.4990951},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '103-10359 104 Street NW',
#     'address2': None,
#     'address3': '',
#     'city': 'Edmonton',
#     'zip_code': 'T5J 1B9',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['103-10359 104 Street NW',
#      'Edmonton, AB T5J 1B9',
#      'Canada']},
#    'phone': '+17804217060',
#    'display_phone': '+1 780-421-7060',
#    'distance': 2030.1727470667724},
#   {'id': 'Hxze1h03tINbqkiE4wQMxg',
#    'alias': 'blowers-and-grafton-edmonton-2',
#    'name': 'Blowers & Grafton',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/0sJP94OqS0I8rK3raEULjg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blowers-and-grafton-edmonton-2?adjust_creative=2tv7N4jCygDlUszgzmAOfg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2tv7N4jCygDlUszgzmAOfg',
#    'review_count': 131,
#    'categories': [{'alias': 'newcanadian', 'title': 'Canadian (New)'}],
#    'rating': 4.2,
#    'coordinates': {'latitude': 53.5184, 'longitude': -113.50278},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '10550 82 Ave NW',
#     'address2': '',
#     'address3': None,
#     'city': 'Edmonton',
#     'zip_code': 'T6E 2A4',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['10550 82 Ave NW', 'Edmonton, AB T6E 2A4', 'Canada']},
#    'phone': '+17802503663',
#    'display_phone': '+1 780-250-3663',
#    'distance': 1239.9833449595055},
#   {'id': '1cSCU9Q9XGBkEDjQMPwq-w',
#    'alias': 'uccellino-edmonton',
#    'name': 'Uccellino',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/K8SweVY6RGiXmZITyyH_Zw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/uccellino-edmonton?adjust_creative=2tv7N4jCygDlUszgzmAOfg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2tv7N4jCygDlUszgzmAOfg',
#    'review_count': 87,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.4,
#    'coordinates': {'latitude': 53.540754, 'longitude': -113.49882542208974},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '10349 Jasper Avenue',
#     'address2': '',
#     'address3': '',
#     'city': 'Edmonton',
#     'zip_code': 'T5J 1Y7',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['10349 Jasper Avenue',
#      'Edmonton, AB T5J 1Y7',
#      'Canada']},
#    'phone': '+17804260346',
#    'display_phone': '+1 780-426-0346',
#    'distance': 1501.9917523706783},
#   {'id': 'Di5B115SVjP3hziLaEGIiA',
#    'alias': 'brasserie-bardot-edmonton',
#    'name': 'Brasserie Bardot',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/k7kkluNmzL-LB8iYFtQGcw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brasserie-bardot-edmonton?adjust_creative=2tv7N4jCygDlUszgzmAOfg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2tv7N4jCygDlUszgzmAOfg',
#    'review_count': 11,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 53.54232, 'longitude': -113.53714},
#    'transactions': [],
#    'location': {'address1': '10109 125 St NW',
#     'address2': '',
#     'address3': None,
#     'city': 'Edmonton',
#     'zip_code': 'T5N 1S7',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['10109 125 St NW', 'Edmonton, AB T5N 1S7', 'Canada']},
#    'phone': '+17807578702',
#    'display_phone': '+1 780-757-8702',
#    'distance': 2368.0840522331314},
#   {'id': 'pqZYSvF_qrmCjkr6frf4RQ',
#    'alias': 'meat-edmonton',
#    'name': 'Meat',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/nTS9uaf70hUG87U-UMqIEA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/meat-edmonton?adjust_creative=2tv7N4jCygDlUszgzmAOfg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2tv7N4jCygDlUszgzmAOfg',
#    'review_count': 476,
#    'categories': [{'alias': 'bbq', 'title': 'Barbeque'},
#     {'alias': 'newcanadian', 'title': 'Canadian (New)'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.2,
#    'coordinates': {'latitude': 53.5186257, 'longitude': -113.4976661},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '8216 104 Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Edmonton',
#     'zip_code': 'T6E 4E6',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['8216 104 Street', 'Edmonton, AB T6E 4E6', 'Canada']},
#    'phone': '+15875206338',
#    'display_phone': '+1 587-520-6338',
#    'distance': 1372.2197901305851},
#   {'id': 'cIBRdoAnPHwEzwxlnq495Q',
#    'alias': 'harvest-room-edmonton',
#    'name': 'Harvest Room',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/srKAZ_jsl47N9WAnnNLs6w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/harvest-room-edmonton?adjust_creative=2tv7N4jCygDlUszgzmAOfg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2tv7N4jCygDlUszgzmAOfg',
#    'review_count': 63,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'newcanadian', 'title': 'Canadian (New)'}],
#    'rating': 4.1,
#    'coordinates': {'latitude': 53.54012, 'longitude': -113.48925},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '10065 - 100th Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Edmonton',
#     'zip_code': 'T5J 0N6',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['10065 - 100th Street',
#      'Edmonton, AB T5J 0N6',
#      'Canada']},
#    'phone': '+17804245181',
#    'display_phone': '+1 780-424-5181',
#    'distance': 1831.9920187387274},
#   {'id': 'lEr79JhaO3O1XqBpD2zENg',
#    'alias': 'sauce-caribbean-edmonton',
#    'name': 'Sauce Caribbean',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/M62Fgvaf8hv3kctq0q2lkw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sauce-caribbean-edmonton?adjust_creative=2tv7N4jCygDlUszgzmAOfg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2tv7N4jCygDlUszgzmAOfg',
#    'review_count': 8,
#    'categories': [{'alias': 'caribbean', 'title': 'Caribbean'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 53.598365, 'longitude': -113.5729618},
#    'transactions': [],
#    'location': {'address1': '13655 St Albert Trail',
#     'address2': None,
#     'address3': '',
#     'city': 'Edmonton',
#     'zip_code': 'T5L 5E7',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['13655 St Albert Trail',
#      'Edmonton, AB T5L 5E7',
#      'Canada']},
#    'phone': '+18254012535',
#    'display_phone': '+1 825-401-2535',
#    'distance': 8791.286038626371},
#   {'id': 'PyRlDfJC81G57YDNr9Nc5Q',
#    'alias': 'sodo-on-jasper-edmonton',
#    'name': 'SoDo on Jasper',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/bO9zhNEnEDercrJuoMBcIQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sodo-on-jasper-edmonton?adjust_creative=2tv7N4jCygDlUszgzmAOfg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2tv7N4jCygDlUszgzmAOfg',
#    'review_count': 9,
#    'categories': [{'alias': 'tradamerican', 'title': 'American'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.8,
#    'coordinates': {'latitude': 53.5407042, 'longitude': -113.5109845},
#    'transactions': [],
#    'location': {'address1': '11011 Jasper Avenue',
#     'address2': '',
#     'address3': None,
#     'city': 'Edmonton',
#     'zip_code': 'T5K 0K6',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['11011 Jasper Avenue',
#      'Edmonton, AB T5K 0K6',
#      'Canada']},
#    'phone': '+17807051101',
#    'display_phone': '+1 780-705-1101',
#    'distance': 1327.6497651354512},
#   {'id': 'fdez0D4ovth2k1IvR0ZbpQ',
#    'alias': 'sabor-edmonton',
#    'name': 'Sabor',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/OTkw-L-93zoKsAqn8GNT_w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sabor-edmonton?adjust_creative=2tv7N4jCygDlUszgzmAOfg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2tv7N4jCygDlUszgzmAOfg',
#    'review_count': 186,
#    'categories': [{'alias': 'portuguese', 'title': 'Portuguese'},
#     {'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 4.3,
#    'coordinates': {'latitude': 53.543381087231,
#     'longitude': -113.497605148344},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '10220 103 Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Edmonton',
#     'zip_code': 'T5J 4A1',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['10220 103 Street', 'Edmonton, AB T5J 4A1', 'Canada']},
#    'phone': '+17807571114',
#    'display_phone': '+1 780-757-1114',
#    'distance': 1799.2030181603875},
#   {'id': '6FPr7wbkqnRlRmFVniwmHg',
#    'alias': 'the-common-edmonton',
#    'name': 'The Common',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/W0qTSp_mfnvLr7P9DBJe1w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-common-edmonton?adjust_creative=2tv7N4jCygDlUszgzmAOfg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2tv7N4jCygDlUszgzmAOfg',
#    'review_count': 170,
#    'categories': [{'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'comfortfood', 'title': 'Comfort Food'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 3.8,
#    'coordinates': {'latitude': 53.53761, 'longitude': -113.5087},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '9910 109th Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Edmonton',
#     'zip_code': 'T5K 1H5',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['9910 109th Street',
#      'Edmonton, AB T5K 1H5',
#      'Canada']},
#    'phone': '+17804527333',
#    'display_phone': '+1 780-452-7333',
#    'distance': 977.9023657219276},
#   {'id': 'O5Wn2RAOA0bzJF6GefbnoQ',
#    'alias': 'waffle-bird-edmonton',
#    'name': 'Waffle Bird',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/kpisjN-LifJmOmdn_GKUAA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/waffle-bird-edmonton?adjust_creative=2tv7N4jCygDlUszgzmAOfg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2tv7N4jCygDlUszgzmAOfg',
#    'review_count': 5,
#    'categories': [{'alias': 'waffles', 'title': 'Waffles'},
#     {'alias': 'chickenshop', 'title': 'Chicken Shop'}],
#    'rating': 4.6,
#    'coordinates': {'latitude': 53.51762, 'longitude': -113.49178},
#    'transactions': [],
#    'location': {'address1': '8116 101 Street NW',
#     'address2': '',
#     'address3': None,
#     'city': 'Edmonton',
#     'zip_code': 'T6E 3Y8',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['8116 101 Street NW',
#      'Edmonton, AB T6E 3Y8',
#      'Canada']},
#    'phone': '+17807527775',
#    'display_phone': '+1 780-752-7775',
#    'distance': 1696.8854978733061},
#   {'id': 'HQYPKYnuVphFs1tDpuVmZw',
#    'alias': 'hus-noodle-nook-edmonton',
#    'name': "Hu's Noodle Nook",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/RddBpDPoWrJ_wF8E63gtCQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hus-noodle-nook-edmonton?adjust_creative=2tv7N4jCygDlUszgzmAOfg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2tv7N4jCygDlUszgzmAOfg',
#    'review_count': 2,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 53.546913, 'longitude': -113.515102},
#    'transactions': [],
#    'location': {'address1': '11238 104 Avenue NW',
#     'address2': '',
#     'address3': None,
#     'city': 'Edmonton',
#     'zip_code': 'T5K 2X4',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['11238 104 Avenue NW',
#      'Edmonton, AB T5K 2X4',
#      'Canada']},
#    'phone': '+17802502600',
#    'display_phone': '+1 780-250-2600',
#    'distance': 2048.765726124417},
#   {'id': 'otGcwLlVcsYK73ULzrLXEA',
#    'alias': 'black-pearl-seafood-bar-downtown-edmonton',
#    'name': 'Black Pearl Seafood Bar-Downtown',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/WyTNSLisPr1hEAMqiyfTcg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/black-pearl-seafood-bar-downtown-edmonton?adjust_creative=2tv7N4jCygDlUszgzmAOfg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2tv7N4jCygDlUszgzmAOfg',
#    'review_count': 109,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.1,
#    'coordinates': {'latitude': 53.541749, 'longitude': -113.49952},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$$',
#    'location': {'address1': '10132 104 Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Edmonton',
#     'zip_code': 'T5J 1A7',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['10132 104 Street', 'Edmonton, AB T5J 1A7', 'Canada']},
#    'phone': '+17807057887',
#    'display_phone': '+1 780-705-7887',
#    'distance': 1580.758111557193},
#   {'id': 'q53QfhzGjznUUADoGANXZw',
#    'alias': 'cork-and-barley-edmonton',
#    'name': 'Cork & Barley',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/EzGzBt3qfIqYbkgXCdhVOw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cork-and-barley-edmonton?adjust_creative=2tv7N4jCygDlUszgzmAOfg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2tv7N4jCygDlUszgzmAOfg',
#    'review_count': 13,
#    'categories': [{'alias': 'comfortfood', 'title': 'Comfort Food'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.4,
#    'coordinates': {'latitude': 53.5979, 'longitude': -113.40834},
#    'transactions': [],
#    'location': {'address1': '4274 137 Avenue NW',
#     'address2': '',
#     'address3': None,
#     'city': 'Edmonton',
#     'zip_code': 'T5Y 2W7',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['4274 137 Avenue NW',
#      'Edmonton, AB T5Y 2W7',
#      'Canada']},
#    'phone': '+17802492675',
#    'display_phone': '+1 780-249-2675',
#    'distance': 10155.096032101366},
#   {'id': '_Hn3IeDxKpBuxoftgiQeAw',
#    'alias': 'taste-of-persia-edmonton',
#    'name': 'Taste Of Persia',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/GVgHhDH1gi-sGCYqlNqKaA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taste-of-persia-edmonton?adjust_creative=2tv7N4jCygDlUszgzmAOfg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2tv7N4jCygDlUszgzmAOfg',
#    'review_count': 5,
#    'categories': [{'alias': 'persian', 'title': 'Persian/Iranian'},
#     {'alias': 'kebab', 'title': 'Kebab'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.8,
#    'coordinates': {'latitude': 53.538344, 'longitude': -113.625314516813},
#    'transactions': [],
#    'location': {'address1': '17620 100 Avenue NW',
#     'address2': '',
#     'address3': None,
#     'city': 'Edmonton',
#     'zip_code': 'T5S 1S9',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['17620 100 Avenue NW',
#      'Edmonton, AB T5S 1S9',
#      'Canada']},
#    'phone': '+17804432525',
#    'display_phone': '+1 780-443-2525',
#    'distance': 7733.042462838584},
#   {'id': 'dsDdbiQeqefDUejpJYHbLA',
#    'alias': 'liberta-coffee-lab-edmonton',
#    'name': 'Liberta Coffee Lab',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/9c7GCkY6WY_XElFQxIVuBA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/liberta-coffee-lab-edmonton?adjust_creative=2tv7N4jCygDlUszgzmAOfg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2tv7N4jCygDlUszgzmAOfg',
#    'review_count': 1,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 53.50243819069463,
#     'longitude': -113.48556055767328},
#    'transactions': [],
#    'location': {'address1': '6547 99 Street NW',
#     'address2': '',
#     'address3': None,
#     'city': 'Edmonton',
#     'zip_code': 'T6E 3P5',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['6547 99 Street NW',
#      'Edmonton, AB T6E 3P5',
#      'Canada']},
#    'phone': '+17808681004',
#    'display_phone': '+1 780-868-1004',
#    'distance': 3328.6512323509037},
#   {'id': 'QitDhCxwX9QR97cSnlKXNQ',
#    'alias': 'eleanor-and-laurent-edmonton',
#    'name': 'Eleanor & Laurent',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/rgI-xJw0Ums080MQFbr0Wg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/eleanor-and-laurent-edmonton?adjust_creative=2tv7N4jCygDlUszgzmAOfg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2tv7N4jCygDlUszgzmAOfg',
#    'review_count': 8,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 53.52412, 'longitude': -113.51326},
#    'transactions': [],
#    'location': {'address1': '10926 88 Avenue NW',
#     'address2': '',
#     'address3': None,
#     'city': 'Edmonton',
#     'zip_code': 'T6G 0Z1',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['10926 88 Avenue NW',
#      'Edmonton, AB T6G 0Z1',
#      'Canada']},
#    'phone': '+17809880897',
#    'display_phone': '+1 780-988-0897',
#    'distance': 589.4147204018122},
#   {'id': 'scnoLACS2mcD_VsPTMOlAA',
#    'alias': 'nongbu-korean-eatery-edmonton',
#    'name': 'Nongbu Korean Eatery',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/sH0qhM1gJIMIRJ8Yq-FzbA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nongbu-korean-eatery-edmonton?adjust_creative=2tv7N4jCygDlUszgzmAOfg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2tv7N4jCygDlUszgzmAOfg',
#    'review_count': 54,
#    'categories': [{'alias': 'korean', 'title': 'Korean'}],
#    'rating': 4.3,
#    'coordinates': {'latitude': 53.51746, 'longitude': -113.49727},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '8115-104 Street NW',
#     'address2': '',
#     'address3': '',
#     'city': 'Edmonton',
#     'zip_code': 'T6E 4E4',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['8115-104 Street NW',
#      'Edmonton, AB T6E 4E4',
#      'Canada']},
#    'phone': '+17809890997',
#    'display_phone': '+1 780-989-0997',
#    'distance': 1494.2694852166649},
#   {'id': '136iuMkyEda_6tmkMI5haw',
#    'alias': 'gyu-kaku-japanese-bbq-edmonton',
#    'name': 'Gyu-Kaku Japanese BBQ',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/LFQes3BmyinccoT-kRujuA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gyu-kaku-japanese-bbq-edmonton?adjust_creative=2tv7N4jCygDlUszgzmAOfg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2tv7N4jCygDlUszgzmAOfg',
#    'review_count': 46,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'bbq', 'title': 'Barbeque'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 3.9,
#    'coordinates': {'latitude': 53.5410649, 'longitude': -113.4995999},
#    'transactions': [],
#    'location': {'address1': '10416 Jasper Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Edmonton',
#     'zip_code': 'T5J 4R5',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['10416 Jasper Ave', 'Edmonton, AB T5J 4R5', 'Canada']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1499.4101753318578},
#   {'id': '0z6gFGDSeb59ZkoSoO7LdQ',
#    'alias': 'otto-food-and-drink-edmonton',
#    'name': 'Otto Food and Drink',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ZzCbWulEufj22KpEL8l4OQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/otto-food-and-drink-edmonton?adjust_creative=2tv7N4jCygDlUszgzmAOfg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2tv7N4jCygDlUszgzmAOfg',
#    'review_count': 80,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 4.6,
#    'coordinates': {'latitude': 53.56448, 'longitude': -113.48682},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '11405 95 Street NW',
#     'address2': '',
#     'address3': None,
#     'city': 'Edmonton',
#     'zip_code': 'T5G 1L3',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['11405 95 Street NW',
#      'Edmonton, AB T5G 1L3',
#      'Canada']},
#    'phone': '+17804776244',
#    'display_phone': '+1 780-477-6244',
#    'distance': 4237.039002607752},
#   {'id': '8AcqFNjZp3gzs66w_g0Aog',
#    'alias': 'the-bedouins-edmonton',
#    'name': 'The Bedouins',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Dyh8cBNfAMqloCP93HdR_Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-bedouins-edmonton?adjust_creative=2tv7N4jCygDlUszgzmAOfg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2tv7N4jCygDlUszgzmAOfg',
#    'review_count': 52,
#    'categories': [{'alias': 'mideastern', 'title': 'Middle Eastern'},
#     {'alias': 'moroccan', 'title': 'Moroccan'}],
#    'rating': 4.8,
#    'coordinates': {'latitude': 53.600692, 'longitude': -113.54282},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '12832 137 Avenue NW',
#     'address2': '',
#     'address3': None,
#     'city': 'Edmonton',
#     'zip_code': 'T5L 4Y8',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['12832 137 Avenue NW',
#      'Edmonton, AB T5L 4Y8',
#      'Canada']},
#    'phone': '+17804786979',
#    'display_phone': '+1 780-478-6979',
#    'distance': 8343.30824247921},
#   {'id': 'dHV02LqcZeVYyKlTO9-Btg',
#    'alias': 'sylv-s-retro-diner-edmonton',
#    'name': 'Sylv’s Retro Diner',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/wiBsymsQu4qyBBCNkOs-Eg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sylv-s-retro-diner-edmonton?adjust_creative=2tv7N4jCygDlUszgzmAOfg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2tv7N4jCygDlUszgzmAOfg',
#    'review_count': 0,
#    'categories': [{'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 0.0,
#    'coordinates': {'latitude': 53.48738, 'longitude': -113.45805},
#    'transactions': [],
#    'location': {'address1': '8707 51 Avenue NW',
#     'address2': '',
#     'address3': None,
#     'city': 'Edmonton',
#     'zip_code': 'T6E 5H1',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['8707 51 Avenue NW',
#      'Edmonton, AB T6E 5H1',
#      'Canada']},
#    'phone': '+17802032886',
#    'display_phone': '+1 780-203-2886',
#    'distance': 5698.467853795055},
#   {'id': 'f9_TLVlUHBv0869CygEbZg',
#    'alias': 'dadeo-edmonton',
#    'name': 'Dadeo',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/omdIPtSgrwG7Rgnh5tE3Pw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dadeo-edmonton?adjust_creative=2tv7N4jCygDlUszgzmAOfg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2tv7N4jCygDlUszgzmAOfg',
#    'review_count': 266,
#    'categories': [{'alias': 'southern', 'title': 'Southern'},
#     {'alias': 'cajun', 'title': 'Cajun/Creole'}],
#    'rating': 4.1,
#    'coordinates': {'latitude': 53.51841, 'longitude': -113.50265},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '10548A 82 Avenue NW',
#     'address2': '',
#     'address3': '',
#     'city': 'Edmonton',
#     'zip_code': 'T6E 2A4',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['10548A 82 Avenue NW',
#      'Edmonton, AB T6E 2A4',
#      'Canada']},
#    'phone': '+17804330930',
#    'display_phone': '+1 780-433-0930',
#    'distance': 1238.6248375053854},
#   {'id': 'Uc1_v_Z9aWMA4w_u4SoRXA',
#    'alias': 'refinery-grill-edmonton',
#    'name': 'Refinery Grill',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/T8S7w5fGeZVXdlsP3INPgQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/refinery-grill-edmonton?adjust_creative=2tv7N4jCygDlUszgzmAOfg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2tv7N4jCygDlUszgzmAOfg',
#    'review_count': 62,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'greek', 'title': 'Greek'}],
#    'rating': 3.8,
#    'coordinates': {'latitude': 53.546627, 'longitude': -113.613707},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '10406 Mayfield Road',
#     'address2': '',
#     'address3': '',
#     'city': 'Edmonton',
#     'zip_code': 'T5P 4P4',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['10406 Mayfield Road',
#      'Edmonton, AB T5P 4P4',
#      'Canada']},
#    'phone': '+17803414904',
#    'display_phone': '+1 780-341-4904',
#    'distance': 7171.4620670371805},
#   {'id': 'VOLeaj3MArFH9WeWGUT5Ig',
#    'alias': 'ralph-s-fried-chicken-edmonton',
#    'name': 'Ralph’s Fried Chicken',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/D-0DYvK9nI0PNl5rEhtH6Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ralph-s-fried-chicken-edmonton?adjust_creative=2tv7N4jCygDlUszgzmAOfg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2tv7N4jCygDlUszgzmAOfg',
#    'review_count': 5,
#    'categories': [{'alias': 'chickenshop', 'title': 'Chicken Shop'}],
#    'rating': 4.6,
#    'coordinates': {'latitude': 53.627702, 'longitude': -113.5077768},
#    'transactions': [],
#    'location': {'address1': '10807 Castle Downs Road',
#     'address2': '',
#     'address3': None,
#     'city': 'Edmonton',
#     'zip_code': 'T5J 0G6',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['10807 Castle Downs Road',
#      'Edmonton, AB T5J 0G6',
#      'Canada']},
#    'phone': '+18778071148',
#    'display_phone': '+1 877-807-1148',
#    'distance': 10997.806499188273},
#   {'id': 'HYiLl8OWiiUSVJpOQyXVsA',
#    'alias': 'biera-edmonton',
#    'name': 'Biera',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/gynsCU54aBdjA-We0oMM_Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/biera-edmonton?adjust_creative=2tv7N4jCygDlUszgzmAOfg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2tv7N4jCygDlUszgzmAOfg',
#    'review_count': 80,
#    'categories': [{'alias': 'beerbar', 'title': 'Beer Bar'},
#     {'alias': 'newcanadian', 'title': 'Canadian (New)'}],
#    'rating': 3.9,
#    'coordinates': {'latitude': 53.51263, 'longitude': -113.476381},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '9570 - 76th Avenue',
#     'address2': '',
#     'address3': None,
#     'city': 'Edmonton',
#     'zip_code': 'T6C 0K2',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['9570 - 76th Avenue',
#      'Edmonton, AB T6C 0K2',
#      'Canada']},
#    'phone': '+15875258589',
#    'display_phone': '+1 587-525-8589',
#    'distance': 2828.6795067070766},
#   {'id': '-jqZKflff1oagRdl2eTg5Q',
#    'alias': 'ashford-house-pub-and-kitchen-edmonton',
#    'name': 'Ashford House Pub & Kitchen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/mAUoOKzvEQgcAJGeAcfZwQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ashford-house-pub-and-kitchen-edmonton?adjust_creative=2tv7N4jCygDlUszgzmAOfg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2tv7N4jCygDlUszgzmAOfg',
#    'review_count': 4,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'irish_pubs', 'title': 'Irish Pub'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 53.5514782, 'longitude': -113.5298359},
#    'transactions': [],
#    'location': {'address1': '12026 107 Avenue NW',
#     'address2': '',
#     'address3': None,
#     'city': 'Edmonton',
#     'zip_code': 'T5H 0Z2',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['12026 107 Avenue NW',
#      'Edmonton, AB T5H 0Z2',
#      'Canada']},
#    'phone': '+15874003204',
#    'display_phone': '+1 587-400-3204',
#    'distance': 2860.3494745137195},
#   {'id': 'ivpULDSBS4mP3mJqmziKQw',
#    'alias': 'cafe-amore-bistro-edmonton-3',
#    'name': 'Cafe Amore Bistro',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/z6lhB60i8EQsVjUU3AWnsg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-amore-bistro-edmonton-3?adjust_creative=2tv7N4jCygDlUszgzmAOfg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2tv7N4jCygDlUszgzmAOfg',
#    'review_count': 150,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.3,
#    'coordinates': {'latitude': 53.5496883, 'longitude': -113.5068932},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '10807 106 Avenue NW',
#     'address2': '',
#     'address3': '',
#     'city': 'Edmonton',
#     'zip_code': 'T5H 4A7',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['10807 106 Avenue NW',
#      'Edmonton, AB T5H 4A7',
#      'Canada']},
#    'phone': '+17804777896',
#    'display_phone': '+1 780-477-7896',
#    'distance': 2328.5128621654544},
#   {'id': '4nBhlO0AZ-YhFjEgntc-wg',
#    'alias': 'flying-dragon-edmonton',
#    'name': 'Flying Dragon',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/dZcjWZmX3Rv9eUYF_riMvQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/flying-dragon-edmonton?adjust_creative=2tv7N4jCygDlUszgzmAOfg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2tv7N4jCygDlUszgzmAOfg',
#    'review_count': 1,
#    'categories': [{'alias': 'taiwanese', 'title': 'Taiwanese'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'hkcafe', 'title': 'Hong Kong Style Cafe'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 53.517321934670136,
#     'longitude': -113.49681247394804},
#    'transactions': [],
#    'location': {'address1': '10336 81 Avenue NW',
#     'address2': None,
#     'address3': '',
#     'city': 'Edmonton',
#     'zip_code': 'T6E 1X2',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['10336 81 Avenue NW',
#      'Edmonton, AB T6E 1X2',
#      'Canada']},
#    'phone': '+17802444004',
#    'display_phone': '+1 780-244-4004',
#    'distance': 1524.102342215033}],
#  'total': 2800,
#  'region': {'center': {'longitude': -113.50936889648438,
#    'latitude': 53.52870361254921}}}

# %% [markdown]
# ## Part 3: Explore your data [Data Analysis - Total 30 pts]
#
# Now that you have created a PySpark dataframe with data from RentFaster and Kijiji, and your code is ready to make requests to the Yelp API, you can begin exploring your data!
#
# You can leverage the Yelp Fusion API, which offers a streamlined method to enrich our web-scraped housing data from RentFaster and Kijiji with detailed information about restaurants, including their ratings, based on specific addresses. This integration enables multi-dimensional analysis, providing insights into the dining landscape surrounding rental listings.
#
# To achieve this, perform the following steps:
#
# 1.   Get the top 50 listings with the highest price from both RentFaster and Kijiji
# (a total of 100 data points, refer to point 1 on **Appendix 1**).
# 2.   Get the bottom 50 listings with the lowest price from both RentFaster and Kijiji (a total of 100 data points, refer to point 2 on **Appendix 1**).
# 3.   Collect the addresses for the top 100 and bottom 100 listings.
# 4.   Perform data cleaning on your address data to remove duplicated locations, if any, from your top and bottom 100 listings.
# 5.  Once you have clean address data, use it to make requests to the Yelp API to obtain a list (in JSON format) of all restaurants near those locations (refer to point 3 on the **Appendix 1**)
# 6.  Create 2 tables using Spark: one for all the restaurants from the top 100 listings and another for those from the bottom 100 listings.
# 7.  Perform a data exploration analysis to try to explain the relationship, if any, between the top/bottom 100 listings and the nearby restaurants. Feel free to create new tables, dataframes, or whatever else you deem necessary for your analysis.
#
# **Apendix 1: Important things to consider!!!**
#
# 1.   The price information for Kijiji listings is stored within the Kijiji overview dataset, in a column called **price_info**. This price is within a JSON string. To retrieve it, use the following approach:
#
# ```
# from pyspark.sql import SparkSession
# from pyspark.sql.functions import col
#
# # Selecting the 'amt' key from the 'price_info' column along with other specified columns
# df = <your_spark_dataframe>.select(
#     col("property_id"),
#     col("listing_url"),
#     col("date_posted"),
#     col("price_info").getItem("amt").alias("amount")
# )
#
# # Show the resulting DataFrame
# df.show()
# ```
#
# 2.   The price information for RentFaster listings is stored within the RentFaster overview dataset, in a column called priceRange. As the name suggests, some listings will have a price range; for those, select the highest price. Use the following approach to clean up the data:
#
# ```
# from pyspark.sql.functions import col, split, expr, regexp_replace, when
#
# df = <your_spark_dataframe>.withColumn(
#     "highestPrice",  # Name of your new column
#     when(
#         col("priceRange").contains(" - "),  # Check if there's a range
#         expr("array_max(transform(split(regexp_replace(priceRange, '\\$|,', ''), ' - '), x -> cast(x as int)))") # Removing $ , - and converting to int
#     ).otherwise(
#         regexp_replace(col("priceRange"), '\\$|,', '').cast("int")  # Handle single price by removing $ and commas and converting to int
#     )
# )
# # Show the resulting DataFrame with the highest price extracted
# df.show(100)
# ```
#
#
#
# 3.   Once you have cleaned your address data, store the addresses in two lists: one for the top 100 listings and another for the bottom 100 listings. You will need to make requests to the API based on these addresses, with ONE request per address. If you have 50 addresses, you need to make 50 requests. **REMEMBER THAT YOU HAVE A DAILY LIMIT**. Here is a code snippet for reference:
#
# ```
# api_key_ = 'YOUR-KEY'
# address = "1039 McConachie Blvd. NW,Edmonton,AB,T5Y 3W5"
#
# headers = {
#     'Authorization': f'Bearer {api_key}',
# }
#
# params = {
#     'term': 'restaurants',
#     'location': address,
#     'limit': 50
# }
# ```
#
# Useful links:
#
# https://docs.developer.yelp.com/reference/v3_business_search
#
# https://spark.apache.org/docs/latest/api/sql/index.html
#
# https://spark.apache.org/docs/latest/sql-ref-functions.html
#
# https://spark.apache.org/docs/latest/api/python/reference/pyspark.sql/functions.html

# %% [markdown]
# # Step 1 (top and bottom 50 listings of kijiji)

# %%
from pyspark.sql.functions import col, from_json
from pyspark.sql.types import StructType, StructField, StringType, IntegerType

#This is to defined the schema of the new column 'price_info_struct'
price_info_schema = StructType([
StructField("amt", IntegerType()),
StructField("cur", StringType()),
StructField("t", StringType())
])

#This is to defined the schema of the new column 'address_struct'
address_schema = StructType([
StructField("address_1", StringType()),
StructField("address_2", StringType())
])

#We add the new column along the schema we defined above, kijiji_overview_spark_df is the data frame you created from the CSV file!
df1 = df_overview_k.withColumn("price_info_struct", from_json(col("price_info"), price_info_schema))
df1 = df1.withColumn("address_struct", from_json(col("address"), address_schema))

#We stract the data from the 'address_struct' and 'price_info_struct' to create 3 new columns 'amount', 'address_1' and 'address_2'
df1_extracted_data = df1.withColumn("amount", col("price_info_struct").amt) \
.withColumn("address_1", col("address_struct").address_1) \
.withColumn("address_2", col("address_struct").address_2)

top_50_kijiji = df1_extracted_data.orderBy(df1_extracted_data['amount'].desc()).limit(50)
bottom_50_kijiji = df1_extracted_data.orderBy(df1_extracted_data['amount'].asc()).limit(50)

top_50_kijiji.show()
bottom_50_kijiji.show()
# Out:
# +----------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+---------+--------------------+--------------------+
# |   unit_id|         listing_url|         date_posted|             address|          price_info|         description|   price_info_struct|      address_struct|   amount|           address_1|           address_2|
# +----------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+---------+--------------------+--------------------+
# |1682780887|https://www.kijij...|   Posted 2 days ago|{'address_1': '61...|{'amt': 360000000...|The standalone bu...|{360000000, CAD, ...|{6108 Bowness Roa...|360000000|6108 Bowness Road...|                NULL|
# |1690661422|https://www.kijij...|Posted 41 minutes...|{'address_1': '97...|{'amt': 1300000, ...|These newly renov...|{1300000, CAD, FI...|{9710, 156 Street...|  1300000|9710, 156 Street,...|9710, 156 Street,...|
# |1690973071|https://www.kijij...|   Posted 2 days ago|{'address_1': 'Ca...|{'amt': 550000, '...|We are leasing ou...|{550000, CAD, FIXED}|{Calgary, AB T2A ...|   550000| Calgary, AB T2A 6K4|                NULL|
# |1643443086|https://www.kijij...|  Posted 16 days ago|{'address_1': '12...|{'cur': 'CAD', 't...|5200 WarehouseAma...|{NULL, CAD, CONTACT}|{12210 Mount Lawn...|  NULL|12210 Mount Lawn ...|                NULL|
# |1663920426|https://www.kijij...|   Posted 2 days ago|{'address_1': '10...|{'cur': 'CAD', 't...|Suite Description...|{NULL, CAD, CONTACT}|{1011 Glenmore Tr...|  NULL|1011 Glenmore Tra...|                NULL|
# |1691007319|https://www.kijij...|   Posted 2 days ago|{'address_1': 'AB...|{'cur': 'CAD', 't...|Currently on assi...|{NULL, CAD, CONTACT}|{AB-2, Edmonton, ...|  NULL|AB-2, Edmonton, A...|AB-2, Edmonton, A...|
# |1672419922|https://www.kijij...|   Posted 2 days ago|{'address_1': '59...|{'cur': 'CAD', 't...|MacLeod Place II ...|{NULL, CAD, CONTACT}|{5920 Macleod Tra...|  NULL|5920 Macleod Trai...|                NULL|
# |1684747882|https://www.kijij...|Posted about 7 ho...|{'address_1': '12...|{'cur': 'CAD', 't...|Brand New  20 Cei...|{NULL, CAD, CONTACT}|{12210 Mount Lawn...|  NULL|12210 Mount Lawn ...|                NULL|
# |1687926540|https://www.kijij...|   Posted 2 days ago|{'address_1': '25...|{'cur': 'CAD', 't...|VILLAGE SQUARE MA...|{NULL, CAD, CONTACT}|{2520 - 52 Street...|  NULL|2520 - 52 Street ...|                NULL|
# |1691004942|https://www.kijij...|   Posted 2 days ago|{'address_1': '90...|{'cur': 'CAD', 't...|Im a 40 year old ...|{NULL, CAD, CONTACT}|{9008 23 Ave NW, ...|  NULL|9008 23 Ave NW, E...|                NULL|
# |1671112995|https://www.kijij...|  Posted 16 days ago|{'address_1': '97...|{'cur': 'CAD', 't...|Over 200000 in le...|{NULL, CAD, CONTACT}|{9742 54 Avenue N...|  NULL|9742 54 Avenue No...|                NULL|
# |1663868429|https://www.kijij...|   Posted 2 days ago|{'address_1': 'Ga...|{'cur': 'CAD', 't...|Prime retail loca...|{NULL, CAD, CONTACT}|{Gasoline Alley w...|  NULL|Gasoline Alley we...|                NULL|
# |1685649783|https://www.kijij...|   Posted 2 days ago|{'address_1': 'Ma...|{'cur': 'CAD', 't...|Detached Double g...|{NULL, CAD, CONTACT}|{Martinvalley Cre...|  NULL|Martinvalley Cres...|                NULL|
# +----------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+------+--------------------+--------------------+
# only showing top 20 rows

# %% [markdown]
# # Step 1 (top and bottom 50 listings of rentfaster)

# %%
from pyspark.sql.functions import col, split, expr, regexp_replace, when

df2 = df_overview_r.withColumn(
    "highestPrice",  # Name of your new column
    when(
        col("priceRange").contains(" - "),  # Check if there's a range
        expr("array_max(transform(split(regexp_replace(priceRange, '\\$|,', ''), ' - '), x -> cast(x as int)))") # Removing $ , - and converting to int
    ).otherwise(
        regexp_replace(col("priceRange"), '\\$|,', '').cast("int")  # Handle single price by removing $ and commas and converting to int
    )
)
top_50_rentfaster = df2.orderBy(col('highestPrice').desc()).limit(50)
bottom_50_rentfaster = df2.orderBy(col('highestPrice').asc()).limit(50)
# Show the resulting DataFrame with the highest price extracted
------+--------------------+--------------------+--------------------+--------------------+----------+--------------------+--------------------+--------------------+--------------------+------------+
# only showing top 20 rows

# %% [markdown]
# # step 3 (collect the top 100 and bottom 100)

# %%
from pyspark.sql.functions import lit

# Renaming columns to make them consistent
top_50_kijiji_renamed = top_50_kijiji.withColumnRenamed('amount', 'price')
top_50_rentfaster_renamed = top_50_rentfaster.withColumn('price', lit(None))

# Selecting common columns
top_50_kijiji_renamed = top_50_kijiji_renamed.select('price', 'address')
top_50_rentfaster_renamed = top_50_rentfaster_renamed.select('price', 'address')

# Combine the top 50 listings from both sources
combined_top_100 = top_50_kijiji_renamed.union(top_50_rentfaster_renamed)

# Sorting the combined DataFrame
combined_top_100_sorted = combined_top_100.orderBy(combined_top_100['price'].desc())

# Collecting the addresses of the top 100 entries
top_100_addresses = combined_top_100_sorted.select('address').rdd.flatMap(lambda x: x).collect()
from tabulate import tabulate

# Convert the DataFrame to a Pandas DataFrame for easier manipulation
combined_top_100_pd = combined_top_100_sorted.toPandas()

# Display the table using tabulate
print(tabulate(combined_top_100_pd, headers='keys', tablefmt='grid'))
# Out:
# +----+--------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |    |        price | address                                                                                                                                                      |
# +====+==============+==============================================================================================================================================================+
# |  0 |      3.6e+08 | {'address_1': '6108 Bowness Road Northwest, Calgary, AB'}                                                                                                    |
# +----+--------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |  1 |      1.3e+06 | {'address_1': '9710, 156 Street, Edmonton, AB, T5P 2P1', 'address_2': '9710, 156 Street, Edmonton, AB, T5P 2P1'}                                             |
# +----+--------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |  2 | 550000       | {'address_1': 'Calgary, AB T2A 6K4'}                                                                                                                         |
# +----+--------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |  3 | 315000       | {'address_1': 'T6B2L7, Canada'}                                                                                                                              |
# +----+--------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |  4 | 300000       | {'address_1': '117 Campbell Crescent, Fort McMurray, AB, T9K 2N3', 'address_2': '117 Campbell Crescent, Fort McMurray, AB, T9K 2N3'}                         |
# +----+--------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |  5 | 299500       | {'address_1': 'Calgary, AB T3G 0A4', 'address_2': 'Calgary, AB T3G 0A4'}                                                                                     |
# +----+--------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |  6 | 291900       | {'address_1': '9733 111th Street, Edmonton, AB, T5K 1J7', 'address_2': '9733 111th Street, Edmonton, AB, T5K 1J7'}                                           |
# +----+--------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |  7 | 280000       | {'address_1': 'New Brighton Walk SE, Calgary, AB T2Z', 'address_2': 'New Brighton Walk SE, Calgary, AB T2Z'}                                                 |
# +----+--------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |  8 | 279500       | {'address_1': '808 1320 1st Street, Calgary, AB, T2G 0Y5'}                                                                                                   |
# +----+--------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |  9 | 279500       | {'address_1': '8710 or 8880 Horton Road, Calgary, AB, T2V 2W3'}                                                                                              |
# +----+--------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | 10 | 278000       | {'address_1': '50 Brentwood Common NW, Calgary, AB, T2L 2M4', 'address_2': '50 Brentwood Common NW, Calgary, AB, T2L 2M4'}                                   |
# +----+--------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | 11 | 275000       | {'address_1': '157 Regal Close, Sherwood Park, AB, T8A 5X9', 'address_2': '157 Regal Close, Sherwood Park, AB, T8A 5X9'}                                     |
# +----+--------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | 12 | 272500       | {'address_1': '11020 Jasper Ave., Edmonton, AB, T5K 2N1', 'address_2': '11020 Jasper Ave., Edmonton, AB, T5K 2N1'}                                           |
# +----+--------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |

# +----+--------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | 86 |    nan       | 8 Chambery Crescent, St. Albert, Alberta, T8T2C1, CA                                                                                                         |
# +----+--------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | 87 |    nan       | 9733 111 St NW, Edmonton, Alberta, T5K1J7, CA                                                                                                                |
# +----+--------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | 88 |    nan       | 10323 121 Street Northwest, Edmonton, Alberta, T5N1K9, CA                                                                                                    |
# +----+--------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | 89 |    nan       | 22135 96 Avenue Northwest, Edmonton, Alberta, T5T1N1, CA                                                                                                     |
# +----+--------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | 90 |    nan       | 168 Windermere Drive Northwest, Edmonton, Alberta, T6W0S4, CA                                                                                                |
# +----+--------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | 91 |    nan       | 15443 133 Street Northwest, Edmonton, Alberta, T6V1G4, CA                                                                                                    |
# +----+--------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | 92 |    nan       | 106 - 10006 83 Ave NW, Edmonton, Alberta, T6E2C2, CA                                                                                                         |
# +----+--------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | 93 |    nan       | 130 Element Dr NW, St. Albert, Alberta, T8N7X2, CA                                                                                                           |
# +----+--------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | 94 |    nan       | 10208 79 Street Northwest, Edmonton, Alberta, T6A3G5, CA                                                                                                     |
# +----+--------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | 95 |    nan       | 3620 166 Avenue Northwest, Edmonton, Alberta, T5Y0N8, CA                                                                                                     |
# +----+--------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | 96 |    nan       | 11329 35 Avenue Northwest, Edmonton, Alberta, T6J3M9, CA                                                                                                     |
# +----+--------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | 97 |    nan       | 2318 Cassidy Way Southwest, Edmonton, Alberta, T6W3L5, CA                                                                                                    |
# +----+--------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | 98 |    nan       | 10217 149 Street, Edmonton, Alberta, T5P1L2, CA                                                                                                              |
# +----+--------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | 99 |    nan       | 1505 - 10226 104 St NW, Edmonton, Alberta, T5J1B8, CA                                                                                                        |
# +----+--------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------+

# %%
bottom_50_kijiji_renamed = bottom_50_kijiji.withColumnRenamed('amount', 'price')
bottom_50_rentfaster_renamed = bottom_50_rentfaster.withColumn('price', lit(None))

# Selecting common columns
bottom_50_kijiji_renamed = bottom_50_kijiji_renamed.select('price', 'address')
bottom_50_rentfaster_renamed = bottom_50_rentfaster_renamed.select('price', 'address')

# Combine the top 50 listings from both sources
combined_bottom_100 = bottom_50_kijiji_renamed.union(bottom_50_rentfaster_renamed)

# Sorting the combined DataFrame
combined_bottom_100_sorted = combined_bottom_100.orderBy(combined_bottom_100['price'].asc())

# Collecting the addresses of the top 100 entries
bottom_100_addresses = combined_bottom_100_sorted.select('address').rdd.flatMap(lambda x: x).collect()
from tabulate import tabulate

# Convert the DataFrame to a Pandas DataFrame for easier manipulation
combined_bottom_100_pd = combined_bottom_100_sorted.toPandas()

# Display the table using tabulate
print(tabulate(combined_bottom_100_pd, headers='keys', tablefmt='grid'))
# Out:
# +----+---------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |    |   price | address                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            |
# +====+=========+====================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================+
# |  0 |     nan | {'address_1': '12210 Mount Lawn Road Northwest, Edmonton, AB'}                                                                                                                                                                                                                                                                                                                                                                                                                                                     |
# +----+---------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |  1 |     nan | {'address_1': 'Fort McMurray, AB T9H 3S3', 'address_2': 'Fort McMurray, AB T9H 3S3'}                                                                                                                                                                                                                                                                                                                                                                                                                               |
# +----+---------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |  2 |     nan | {'address_1': '11231 Macdonald Drive, Fort McMurray, AB'}                                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# +----+---------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |  3 |     nan | {'Undefined': 'Undefined'}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |
# +----+---------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |  4 |     nan | {'Undefined': 'Undefined'}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |
# +----+---------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |  5 |     nan | {'Undefined': 'Undefined'}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |
# +----+---------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |  6 |     nan | {'Undefined': 'Undefined'}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |
# +----+---------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |  7 |     nan | {'Undefined': 'Undefined'}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |
# +----+---------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |
}                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |
# +----+---------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | 39 |     nan | {'address_1': '#7-11703 51 Avenue NW, Edmonton, AB, T6H 0M4', 'address_2': '#7-11703 51 Avenue NW, Edmonton, AB, T6H 0M4'}                                                                                                                                                                                                                                                                                                                                                                                         |
# +----+---------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | 40 |     nan | {'address_1': '13703 135 Ave NW, Edmonton, AB'}                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |
# +----+---------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | 41 |     nan | {'Undefined': 'Undefined'}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |
# +----+---------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | 42 |     nan | {'Undefined': 'Undefined'}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |
# +----+---------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | 43 |     nan | {'address_1': '11240 199 Street Northwest, Edmonton, AB'}                                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# +----+---------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | 44 |     nan | {'address_1': '11240 199th Street Northwest, Edmonton, AB'}                                                                                                                                                                                                                                                                                                                                                                                                                                                        |
# ...
# | 85 |     nan | 18035 Stony Plain Road, Edmonton, Alberta, T0B3M2, CA                                                                                                                                                                                                                                                                                                                                                                                                                                                              |
# +----+---------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | 86 |     nan | 202 - 10604 110 Avenue NW, Edmonton, Alberta, T5H4C7, CA                                                                                                                                                                                                                                                                                                                                                                                                                                                           |
# +----+---------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | 87 |     nan | 8116 123 Avenue Northwest, Edmonton, Alberta, T5B1B3, CA                                                                                                                                                                                                                                                                                                                                                                                                                                                           |
# +----+---------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | 88 |     nan | BSMT 9347 105 Avenue Northwest, Edmonton, Alberta, T5H0J6, CA                                                                                                                                                                                                                                                                                                                                                                                                                                                      |
# +----+---------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | 89 |     nan | 1472 (Bsmt) Keswick Drive Southwest - Bsmt Edmonton AB T6W 1A5, Edmonton, Alberta, T6W1A5, CA                                                                                                                                                                                                                                                                                                                                                                                                                      |
# +----+---------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | 90 |     nan | 2731 Orchards Road Southwest, Edmonton, Alberta, T6X1A2, CA                                                                                                                                                                                                                                                                                                                                                                                                                                                        |
# +----+---------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | 91 |     nan | 11735 124 Street, Edmonton, Alberta, T5M0L1, CA                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |
# +----+---------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | 92 |     nan | 11262 78 Avenue Northwest, Edmonton, Alberta, T6G0M7, CA                                                                                                                                                                                                                                                                                                                                                                                                                                                           |
# +----+---------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | 93 |     nan | 2828 193 St NW, Edmonton, Alberta, T6M3B2, CA                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |
# +----+---------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | 94 |     nan | Challand Ln, Edmonton, Alberta, T6W0C3, CA                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |
# +----+---------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | 95 |     nan | 12926 124 Street, Edmonton, Alberta, T5L0P5, CA                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |
# +----+---------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | 96 |     nan | 12936 118 Avenue, Edmonton, Alberta, T5L2L4, CA                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |
# +----+---------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | 97 |    1600 | {'address_1': '3 St SE, Calgary, AB T2G 2S8, Canada'}                                                                                                                                                                                                                                                                                                                                                                                                                                                              |
# +----+---------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | 98 |    1800 | {'address_1': 'Edmonton, AB T5M 2S9'}                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |
# +----+---------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | 99 |    3500 | {'address_1': 'Calmar, AB, Canada'}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                |
# +----+---------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+

# %% [markdown]
# # Remove Duplicate locations

# %%
combined_top_100_unique = combined_top_100_sorted.dropDuplicates(['address'])

# Convert the DataFrame to a Pandas DataFrame for easier manipulation
combined_top_100_pd_unique = combined_top_100_unique.toPandas()

# Display the table using tabulate
print(tabulate(combined_top_100_pd_unique, headers='keys', tablefmt='grid'))

combined_bottom_100_unique = combined_bottom_100_sorted.dropDuplicates(['address'])

# Convert the DataFrame to a Pandas DataFrame for easier manipulation
combined_bottom_100_pd_unique = combined_bottom_100_unique.toPandas()

# Display the table using tabulate
print(tabulate(combined_bottom_100_pd_unique, headers='keys', tablefmt='grid'))
# Out:
# +----+--------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |    |        price | address                                                                                                                                                      |
# +====+==============+==============================================================================================================================================================+
# |  0 | 213900       | {'address_1': '2010 Ulster Rd. NW, Calgary, AB, T2N 4C2', 'address_2': '2010 Ulster Rd. NW, Calgary, AB, T2N 4C2'}                                           |
# +----+--------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |  1 | 230000       | {'address_1': 'Tuscany Springs Gardens NW, Calgary, AB T3L 2R4', 'address_2': 'Tuscany Springs Gardens NW, Calgary, AB T3L 2R4'}                             |
# +----+--------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |  2 |    nan       | 3620 166 Avenue Northwest, Edmonton, Alberta, T5Y0N8, CA                                                                                                     |
# +----+--------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |  3 | 210000       | {'address_1': 'Palliser Drive Southwest, Calgary, AB', 'address_2': 'Palliser Drive Southwest, Calgary, AB'}                                                 |
# +----+--------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |

# +----+---------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |  6 |     nan | {'address_1': 'Martinvalley Crescent NE, Calgary, AB T3J'}                                                                                                                                                                                                                                                                                                                                                                                                                                                         |
# +----+---------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |  7 |     nan | 187 Grandin Village, St. Albert, Alberta, T8N2J3, CA                                                                                                                                                                                                                                                                                                                                                                                                                                                               |
# +----+---------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |  8 |     nan | 4807 111A Street Northwest, Edmonton, Alberta, T6H3G4, CA                                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# +----+---------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |  9 |     nan | {'address_1': '11231 Macdonald Drive, Fort McMurray, AB'}                                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# +----+---------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# ...
# | 59 |     nan | {'address_1': 'Calgary, AB T2R 1S6'}                                                                                                                                                                                                                                                                                                                                                                                                                                                                               |
# +----+---------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | 60 |     nan | {'address_1': '1013 17th Ave Sw, Calgary, AB, T2T 0A7'}                                                                                                                                                                                                                                                                                                                                                                                                                                                            |
# +----+---------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | 61 |     nan | 20 Circle Drive, St. Albert, Alberta, T8N7L4, CA                                                                                                                                                                                                                                                                                                                                                                                                                                                                   |
# +----+---------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | 62 |     nan | {'address_1': 'Street North, Lethbridge, Alberta T1H 2R4'}                                                                                                                                                                                                                                                                                                                                                                                                                                                         |
# +----+---------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | 63 |     nan | {'address_1': '41427 Range Rd 20, LACOMBE COUNTY, T0C 2J0', 'address_2': '41427 Range Rd 20, LACOMBE COUNTY, T0C 2J0'}                                                                                                                                                                                                                                                                                                                                                                                             |
# +----+---------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | 64 |     nan | 12926 124 Street, Edmonton, Alberta, T5L0P5, CA                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |
# +----+---------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | 65 |     nan | {'address_1': '1011 Glenmore Trail SW, Calgary, AB, T2V 4R6'}                                                                                                                                                                                                                                                                                                                                                                                                                                                      |
# +----+---------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | 66 |     nan | 5029 34 Street, Red Deer, Alberta, T4N0P4, CA                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |
# +----+---------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | 67 |     nan | 5 - 11928 129 Avenue Northwest, Edmonton, Alberta, T5E0N3, CA                                                                                                                                                                                                                                                                                                                                                                                                                                                      |
# +----+---------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | 68 |     nan | 212 - 8510 111 Street Northwest, Edmonton, Alberta, T3K5Z1, CA                                                                                                                                                                                                                                                                                                                                                                                                                                                     |
# +----+---------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | 69 |     nan | {'address_1': 'Lethbridge, AB T1K', 'address_2': 'Lethbridge, AB T1K'}                                                                                                                                                                                                                                                                                                                                                                                                                                             |
# +----+---------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | 70 |     nan | {'address_1': 'Fox Creek, AB T0H 1P0', 'address_2': 'Fox Creek, AB T0H 1P0'}                                                                                                                                                                                                                                                                                                                                                                                                                                       |
# +----+---------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | 71 |     nan | 9999 111 Street Northwest, Edmonton, Alberta, T5K1K3, CA                                                                                                                                                                                                                                                                                                                                                                                                                                                           |
# +----+---------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | 72 |     nan | 17312 111 Street Northwest, Edmonton, Alberta, T5X3J8, CA                                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# +----+---------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | 73 |     nan | 201 - 12103 67 Street Northwest, Edmonton, Alberta, T5W3R5, CA                                                                                                                                                                                                                                                                                                                                                                                                                                                     |
# +----+---------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+

# %%
# !pip install pandas
import pandas as pd
import requests

api_key = '8eqjzK3BpkTDsYgV_Iatj5LPlJLfco7sTo-i31B0x2VrE4hSOuBSrO79fOY1V6sUAQa6q6zl1epiuxKcGjarWOx7KfkflMos1f7gcLbz5-XZDMsuSgzGxYwZbH8eZnYx'

# Function to make requests to the Yelp API for restaurants near a given address
def get_restaurants_near_address(address):
    url = 'https://api.yelp.com/v3/businesses/search'
    headers = {
        'Authorization': f'Bearer {api_key}',
    }
    params = {
        'term': 'restaurants',
        'location': address,
        'limit': 50
    }
    response = requests.get(url, headers=headers, params=params)
    return response.json()

# Assuming you have cleaned address data and stored it in two lists: top_100_addresses and bottom_100_addresses

# Make requests for top 100 addresses
top_100_restaurants = []
for address in combined_top_100_pd_unique:
    response = get_restaurants_near_address(address)
    top_100_restaurants.append(response)

# Make requests for bottom 100 addresses
bottom_100_restaurants = []
for address in combined_bottom_100_pd_unique:
    response2 = get_restaurants_near_address(address)
    bottom_100_restaurants.append(response2)

print(top_100_restaurants)
print(bottom_100_restaurants)
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.25.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# [{'businesses': [{'id': 'N51hLGrZ9nBvXukSw4iMqA', 'alias': 'tangerine-eatery-price', 'name': 'Tangerine Eatery', 'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto
# %% [markdown]
# # Create Dataframes for top and bottom 100

# %%
spark = SparkSession.builder \
    .appName("RestaurantAnalysis") \
    .getOrCreate()

schema = StructType([
    StructField("businesses", StringType(), True),
    StructField("region", StringType(), True),
    StructField("total", IntegerType(), True),
    StructField("error", StringType(), True)
])

# Convert Pandas DataFrames to Spark DataFrames with defined schema
top_100_spark_df = spark.createDataFrame(top_100_restaurants, schema=schema)
bottom_100_spark_df = spark.createDataFrame(bottom_100_restaurants, schema=schema)

# Register Spark DataFrames as temporary tables
top_100_spark_df.createOrReplaceTempView("top_100_restaurants")
bottom_100_spark_df.createOrReplaceTempView("bottom_100_restaurants")

# Example queries
top_100_query = spark.sql("SELECT * FROM top_100_restaurants LIMIT 10")
bottom_100_query = spark.sql("SELECT * FROM bottom_100_restaurants LIMIT 10")

# Show the results
print("Top 100 Restaurants:")
top_100_query.show()
print("Bottom 100 Restaurants:")
bottom_100_query.show()
# Out:
# Top 100 Restaurants:
# +--------------------+--------------------+-----+--------------------+
# |          businesses|              region|total|               error|
# +--------------------+--------------------+-----+--------------------+
# |[{distance=721.86...|{center={latitude...|   39|                NULL|
# |                NULL|                NULL| NULL|{description=Coul...|
# +--------------------+--------------------+-----+--------------------+
#
# Bottom 100 Restaurants:
# +--------------------+--------------------+-----+--------------------+
# |          businesses|              region|total|               error|
# +--------------------+--------------------+-----+--------------------+
# |[{distance=721.86...|{center={latitude...|   39|                NULL|
# |                NULL|                NULL| NULL|{description=Coul...|
# +--------------------+--------------------+-----+--------------------+

# %% [markdown]
# # Explore relationships
# To explore the relationship between the top/bottom 100 restaurants and restaurants near to them, we can compare the company under which they are working, what is the distance between them, what region they belong to. we can also clean and preprocess the data to extract information from the business column, we can also compare the restaurant category and their ratings or when they were opened. We can also compare the top and bottom 100 restaurants to analyze the differences between them to know why their prices are so different. <br>
# <br>
# Now, there is a difference in the region the restaurants are located. It has a great impact on the pricing. we see that inn the top 100 restaurants list, there are mostly the restaurants which are located near highways or much busy roads. These are much expensive. However, the ones in bottom category are cheaper. <br>
# <br>
# Also, when we look at description provided in the overview files, we can see that expensive restaurants provide much more facilities than the cheaper one. The ratings are also high for the top restaurants because of better service.

# %% [markdown]
# ## Part 4: Presentation (30 pts)
#
# You will need to create a presentation that would last 10 to 15 min. All memebers for the group should participate. This presentation will be conducted on Monday 22th and Tuesday 23th of April.
#
# In this presentation you will need to explain your findings from your data collection, managmenet and exploration. This must include everything such as corrupted data, data cleaning, data transformation, errors when scraping from websitews, data analysis, data limitations etc. You should showcase your work in its fullest!
#
# What we are specifically looking is the following:
# *   Issues faced acquiring your data, this could be limitations with the webscraping procedure
# *   Data quality issues such as missing values or difficulties when working with multiple datatypes and how to solve/consider those in your analysis
# *   The highlights and correlations that you derived based on the analysis of the data, you should be able to answer the following questions:
#   * Is there a correlation between the rental price vs the quality/price on restaurants near by?
#   * Is the data coming from Yelp of enough quality to drive insides?
#   * What you would do better or different to arrive to a more conclusive analysis?
#   * What are your next steps?
#   * Is this datapipeline you built enough to scale for big data?
